# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %% [markdown]
# Importante: O exemplo GIANTSTEPS3519546.LOFI não pode ser utilizado. Tempo mais curto que a janela.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import shutil
#shutil.copy2("/content/drive/MyDrive/utilities.py", "/content/utilities.py")
#shutil.copy2("/content/drive/MyDrive/ConvNet3DSpecShanMorl.py", "/content/ConvNet3DSpecShanMorl.py")
#shutil.copy2("/content/drive/MyDrive/config.py", "/content/config.py")
# Out:
# '/content/config.py'

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adagrad
from tensorflow.keras.utils import to_categorical
from tensorflow.data import AUTOTUNE
import matplotlib.pyplot as plt
import tensorflow as tf
import argparse
import os
import numpy as np
import pandas as pd
import math
from tensorflow import keras
from sklearn.preprocessing import MultiLabelBinarizer
from IPython.display import Audio, clear_output, display
from glob import glob
import random

from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import layers, models

# %%
BS = 32 #batch size

base_model = EfficientNetB0(input_shape=(300, 300, 3), include_top=False, weights='imagenet')

x = base_model.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dropout(0.3)(x)
output = layers.Dense(10, activation='softmax')(x)

model = models.Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 300, 300,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 300, 300,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization       │ (None, 300, 300,  │          7 │ rescaling[0][0]   │
# │ (Normalization)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_1         │ (None, 300, 300,  │          0 │ normalization[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv_pad       │ (None, 301, 301,  │          0 │ rescaling_1[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 150, 150,  │        864 │ stem_conv_pad[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn             │ (None, 150, 150,  │        128 │ stem_conv[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_activation     │ (None, 150, 150,  │          0 │ stem_bn[0][0]     │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_dwconv      │ (None, 150, 150,  │        288 │ stem_activation[… │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_bn          │ (None, 150, 150,  │        128 │ block1a_dwconv[0… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_activation  │ (None, 150, 150,  │          0 │ block1a_bn[0][0]  │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_squeeze  │ (None, 32)        │          0 │ block1a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reshape  │ (None, 1, 1, 32)  │          0 │ block1a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reduce   │ (None, 1, 1, 8)   │        264 │ block1a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_expand   │ (None, 1, 1, 32)  │        288 │ block1a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_excite   │ (None, 150, 150,  │          0 │ block1a_activati… │
# │ (Multiply)          │ 32)               │            │ block1a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_co… │ (None, 150, 150,  │        512 │ block1a_se_excit… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_bn  │ (None, 150, 150,  │         64 │ block1a_project_… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_conv │ (None, 150, 150,  │      1,536 │ block1a_project_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_bn   │ (None, 150, 150,  │        384 │ block2a_expand_c… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_act… │ (None, 150, 150,  │          0 │ block2a_expand_b… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv_pad  │ (None, 151, 151,  │          0 │ block2a_expand_a… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv      │ (None, 75, 75,    │        864 │ block2a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_bn          │ (None, 75, 75,    │        384 │ block2a_dwconv[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_activation  │ (None, 75, 75,    │          0 │ block2a_bn[0][0]  │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_squeeze  │ (None, 96)        │          0 │ block2a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reshape  │ (None, 1, 1, 96)  │          0 │ block2a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reduce   │ (None, 1, 1, 4)   │        388 │ block2a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_expand   │ (None, 1, 1, 96)  │        480 │ block2a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_excite   │ (None, 75, 75,    │          0 │ block2a_activati… │
# │ (Multiply)          │ 96)               │            │ block2a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_co… │ (None, 75, 75,    │      2,304 │ block2a_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_bn  │ (None, 75, 75,    │         96 │ block2a_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_conv │ (None, 75, 75,    │      3,456 │ block2a_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_bn   │ (None, 75, 75,    │        576 │ block2b_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_act… │ (None, 75, 75,    │          0 │ block2b_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_dwconv      │ (None, 75, 75,    │      1,296 │ block2b_expand_a… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_bn          │ (None, 75, 75,    │        576 │ block2b_dwconv[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_activation  │ (None, 75, 75,    │          0 │ block2b_bn[0][0]  │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_squeeze  │ (None, 144)       │          0 │ block2b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reshape  │ (None, 1, 1, 144) │          0 │ block2b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reduce   │ (None, 1, 1, 6)   │        870 │ block2b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_expand   │ (None, 1, 1, 144) │      1,008 │ block2b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_excite   │ (None, 75, 75,    │          0 │ block2b_activati… │
# │ (Multiply)          │ 144)              │            │ block2b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_co… │ (None, 75, 75,    │      3,456 │ block2b_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_bn  │ (None, 75, 75,    │         96 │ block2b_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_drop        │ (None, 75, 75,    │          0 │ block2b_project_… │
# │ (Dropout)           │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_add (Add)   │ (None, 75, 75,    │          0 │ block2b_drop[0][… │
# │                     │ 24)               │            │ block2a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_conv │ (None, 75, 75,    │      3,456 │ block2b_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_bn   │ (None, 75, 75,    │        576 │ block3a_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_act… │ (None, 75, 75,    │          0 │ block3a_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv_pad  │ (None, 79, 79,    │          0 │ block3a_expand_a… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv      │ (None, 38, 38,    │      3,600 │ block3a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_bn          │ (None, 38, 38,    │        576 │ block3a_dwconv[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_activation  │ (None, 38, 38,    │          0 │ block3a_bn[0][0]  │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_squeeze  │ (None, 144)       │          0 │ block3a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reshape  │ (None, 1, 1, 144) │          0 │ block3a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reduce   │ (None, 1, 1, 6)   │        870 │ block3a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_expand   │ (None, 1, 1, 144) │      1,008 │ block3a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_excite   │ (None, 38, 38,    │          0 │ block3a_activati… │
# │ (Multiply)          │ 144)              │            │ block3a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_co… │ (None, 38, 38,    │      5,760 │ block3a_se_excit… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_bn  │ (None, 38, 38,    │        160 │ block3a_project_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_conv │ (None, 38, 38,    │      9,600 │ block3a_project_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_bn   │ (None, 38, 38,    │        960 │ block3b_expand_c… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_act… │ (None, 38, 38,    │          0 │ block3b_expand_b… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_dwconv      │ (None, 38, 38,    │      6,000 │ block3b_expand_a… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_bn          │ (None, 38, 38,    │        960 │ block3b_dwconv[0… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_activation  │ (None, 38, 38,    │          0 │ block3b_bn[0][0]  │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_squeeze  │ (None, 240)       │          0 │ block3b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reshape  │ (None, 1, 1, 240) │          0 │ block3b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reduce   │ (None, 1, 1, 10)  │      2,410 │ block3b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_expand   │ (None, 1, 1, 240) │      2,640 │ block3b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_excite   │ (None, 38, 38,    │          0 │ block3b_activati… │
# │ (Multiply)          │ 240)              │            │ block3b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_co… │ (None, 38, 38,    │      9,600 │ block3b_se_excit… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_bn  │ (None, 38, 38,    │        160 │ block3b_project_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_drop        │ (None, 38, 38,    │          0 │ block3b_project_… │
# │ (Dropout)           │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_add (Add)   │ (None, 38, 38,    │          0 │ block3b_drop[0][… │
# │                     │ 40)               │            │ block3a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_conv │ (None, 38, 38,    │      9,600 │ block3b_add[0][0] │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_bn   │ (None, 38, 38,    │        960 │ block4a_expand_c… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_act… │ (None, 38, 38,    │          0 │ block4a_expand_b… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv_pad  │ (None, 39, 39,    │          0 │ block4a_expand_a… │
# │ (ZeroPadding2D)     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv      │ (None, 19, 19,    │      2,160 │ block4a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_bn          │ (None, 19, 19,    │        960 │ block4a_dwconv[0… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_activation  │ (None, 19, 19,    │          0 │ block4a_bn[0][0]  │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_squeeze  │ (None, 240)       │          0 │ block4a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reshape  │ (None, 1, 1, 240) │          0 │ block4a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reduce   │ (None, 1, 1, 10)  │      2,410 │ block4a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_expand   │ (None, 1, 1, 240) │      2,640 │ block4a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_excite   │ (None, 19, 19,    │          0 │ block4a_activati… │
# │ (Multiply)          │ 240)              │            │ block4a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_co… │ (None, 19, 19,    │     19,200 │ block4a_se_excit… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_bn  │ (None, 19, 19,    │        320 │ block4a_project_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_conv │ (None, 19, 19,    │     38,400 │ block4a_project_… │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_bn   │ (None, 19, 19,    │      1,920 │ block4b_expand_c… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_act… │ (None, 19, 19,    │          0 │ block4b_expand_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_dwconv      │ (None, 19, 19,    │      4,320 │ block4b_expand_a… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_bn          │ (None, 19, 19,    │      1,920 │ block4b_dwconv[0… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_activation  │ (None, 19, 19,    │          0 │ block4b_bn[0][0]  │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_squeeze  │ (None, 480)       │          0 │ block4b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reshape  │ (None, 1, 1, 480) │          0 │ block4b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block4b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_expand   │ (None, 1, 1, 480) │     10,080 │ block4b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_excite   │ (None, 19, 19,    │          0 │ block4b_activati… │
# │ (Multiply)          │ 480)              │            │ block4b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_co… │ (None, 19, 19,    │     38,400 │ block4b_se_excit… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_bn  │ (None, 19, 19,    │        320 │ block4b_project_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_drop        │ (None, 19, 19,    │          0 │ block4b_project_… │
# │ (Dropout)           │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_add (Add)   │ (None, 19, 19,    │          0 │ block4b_drop[0][… │
# │                     │ 80)               │            │ block4a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_conv │ (None, 19, 19,    │     38,400 │ block4b_add[0][0] │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_bn   │ (None, 19, 19,    │      1,920 │ block4c_expand_c… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_act… │ (None, 19, 19,    │          0 │ block4c_expand_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_dwconv      │ (None, 19, 19,    │      4,320 │ block4c_expand_a… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_bn          │ (None, 19, 19,    │      1,920 │ block4c_dwconv[0… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_activation  │ (None, 19, 19,    │          0 │ block4c_bn[0][0]  │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_squeeze  │ (None, 480)       │          0 │ block4c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reshape  │ (None, 1, 1, 480) │          0 │ block4c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block4c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_expand   │ (None, 1, 1, 480) │     10,080 │ block4c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_excite   │ (None, 19, 19,    │          0 │ block4c_activati… │
# │ (Multiply)          │ 480)              │            │ block4c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_co… │ (None, 19, 19,    │     38,400 │ block4c_se_excit… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_bn  │ (None, 19, 19,    │        320 │ block4c_project_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_drop        │ (None, 19, 19,    │          0 │ block4c_project_… │
# │ (Dropout)           │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_add (Add)   │ (None, 19, 19,    │          0 │ block4c_drop[0][… │
# │                     │ 80)               │            │ block4b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_conv │ (None, 19, 19,    │     38,400 │ block4c_add[0][0] │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_bn   │ (None, 19, 19,    │      1,920 │ block5a_expand_c… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_act… │ (None, 19, 19,    │          0 │ block5a_expand_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_dwconv      │ (None, 19, 19,    │     12,000 │ block5a_expand_a… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_bn          │ (None, 19, 19,    │      1,920 │ block5a_dwconv[0… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_activation  │ (None, 19, 19,    │          0 │ block5a_bn[0][0]  │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_squeeze  │ (None, 480)       │          0 │ block5a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reshape  │ (None, 1, 1, 480) │          0 │ block5a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block5a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_expand   │ (None, 1, 1, 480) │     10,080 │ block5a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_excite   │ (None, 19, 19,    │          0 │ block5a_activati… │
# │ (Multiply)          │ 480)              │            │ block5a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_co… │ (None, 19, 19,    │     53,760 │ block5a_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_bn  │ (None, 19, 19,    │        448 │ block5a_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_conv │ (None, 19, 19,    │     75,264 │ block5a_project_… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_bn   │ (None, 19, 19,    │      2,688 │ block5b_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_act… │ (None, 19, 19,    │          0 │ block5b_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_dwconv      │ (None, 19, 19,    │     16,800 │ block5b_expand_a… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_bn          │ (None, 19, 19,    │      2,688 │ block5b_dwconv[0… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_activation  │ (None, 19, 19,    │          0 │ block5b_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_squeeze  │ (None, 672)       │          0 │ block5b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reshape  │ (None, 1, 1, 672) │          0 │ block5b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block5b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_expand   │ (None, 1, 1, 672) │     19,488 │ block5b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_excite   │ (None, 19, 19,    │          0 │ block5b_activati… │
# │ (Multiply)          │ 672)              │            │ block5b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_co… │ (None, 19, 19,    │     75,264 │ block5b_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_bn  │ (None, 19, 19,    │        448 │ block5b_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_drop        │ (None, 19, 19,    │          0 │ block5b_project_… │
# │ (Dropout)           │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_add (Add)   │ (None, 19, 19,    │          0 │ block5b_drop[0][… │
# │                     │ 112)              │            │ block5a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_conv │ (None, 19, 19,    │     75,264 │ block5b_add[0][0] │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_bn   │ (None, 19, 19,    │      2,688 │ block5c_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_act… │ (None, 19, 19,    │          0 │ block5c_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_dwconv      │ (None, 19, 19,    │     16,800 │ block5c_expand_a… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_bn          │ (None, 19, 19,    │      2,688 │ block5c_dwconv[0… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_activation  │ (None, 19, 19,    │          0 │ block5c_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_squeeze  │ (None, 672)       │          0 │ block5c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reshape  │ (None, 1, 1, 672) │          0 │ block5c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block5c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_expand   │ (None, 1, 1, 672) │     19,488 │ block5c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_excite   │ (None, 19, 19,    │          0 │ block5c_activati… │
# │ (Multiply)          │ 672)              │            │ block5c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_co… │ (None, 19, 19,    │     75,264 │ block5c_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_bn  │ (None, 19, 19,    │        448 │ block5c_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_drop        │ (None, 19, 19,    │          0 │ block5c_project_… │
# │ (Dropout)           │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_add (Add)   │ (None, 19, 19,    │          0 │ block5c_drop[0][… │
# │                     │ 112)              │            │ block5b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_conv │ (None, 19, 19,    │     75,264 │ block5c_add[0][0] │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_bn   │ (None, 19, 19,    │      2,688 │ block6a_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_act… │ (None, 19, 19,    │          0 │ block6a_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_dwconv_pad  │ (None, 23, 23,    │          0 │ block6a_expand_a… │
# │ (ZeroPadding2D)     │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_dwconv      │ (None, 10, 10,    │     16,800 │ block6a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_bn          │ (None, 10, 10,    │      2,688 │ block6a_dwconv[0… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_activation  │ (None, 10, 10,    │          0 │ block6a_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_squeeze  │ (None, 672)       │          0 │ block6a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reshape  │ (None, 1, 1, 672) │          0 │ block6a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block6a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_expand   │ (None, 1, 1, 672) │     19,488 │ block6a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_excite   │ (None, 10, 10,    │          0 │ block6a_activati… │
# │ (Multiply)          │ 672)              │            │ block6a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_project_co… │ (None, 10, 10,    │    129,024 │ block6a_se_excit… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_project_bn  │ (None, 10, 10,    │        768 │ block6a_project_… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_conv │ (None, 10, 10,    │    221,184 │ block6a_project_… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_bn   │ (None, 10, 10,    │      4,608 │ block6b_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_act… │ (None, 10, 10,    │          0 │ block6b_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_dwconv      │ (None, 10, 10,    │     28,800 │ block6b_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_bn          │ (None, 10, 10,    │      4,608 │ block6b_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_activation  │ (None, 10, 10,    │          0 │ block6b_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_squeeze  │ (None, 1152)      │          0 │ block6b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_reshape  │ (None, 1, 1,      │          0 │ block6b_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_expand   │ (None, 1, 1,      │     56,448 │ block6b_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_excite   │ (None, 10, 10,    │          0 │ block6b_activati… │
# │ (Multiply)          │ 1152)             │            │ block6b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_project_co… │ (None, 10, 10,    │    221,184 │ block6b_se_excit… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_project_bn  │ (None, 10, 10,    │        768 │ block6b_project_… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_drop        │ (None, 10, 10,    │          0 │ block6b_project_… │
# │ (Dropout)           │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_add (Add)   │ (None, 10, 10,    │          0 │ block6b_drop[0][… │
# │                     │ 192)              │            │ block6a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_conv │ (None, 10, 10,    │    221,184 │ block6b_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_bn   │ (None, 10, 10,    │      4,608 │ block6c_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_act… │ (None, 10, 10,    │          0 │ block6c_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_dwconv      │ (None, 10, 10,    │     28,800 │ block6c_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_bn          │ (None, 10, 10,    │      4,608 │ block6c_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_activation  │ (None, 10, 10,    │          0 │ block6c_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_squeeze  │ (None, 1152)      │          0 │ block6c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_reshape  │ (None, 1, 1,      │          0 │ block6c_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_expand   │ (None, 1, 1,      │     56,448 │ block6c_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_excite   │ (None, 10, 10,    │          0 │ block6c_activati… │
# │ (Multiply)          │ 1152)             │            │ block6c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_project_co… │ (None, 10, 10,    │    221,184 │ block6c_se_excit… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_project_bn  │ (None, 10, 10,    │        768 │ block6c_project_… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_drop        │ (None, 10, 10,    │          0 │ block6c_project_… │
# │ (Dropout)           │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_add (Add)   │ (None, 10, 10,    │          0 │ block6c_drop[0][… │
# │                     │ 192)              │            │ block6b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_conv │ (None, 10, 10,    │    221,184 │ block6c_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_bn   │ (None, 10, 10,    │      4,608 │ block6d_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_act… │ (None, 10, 10,    │          0 │ block6d_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_dwconv      │ (None, 10, 10,    │     28,800 │ block6d_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_bn          │ (None, 10, 10,    │      4,608 │ block6d_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_activation  │ (None, 10, 10,    │          0 │ block6d_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_squeeze  │ (None, 1152)      │          0 │ block6d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_reshape  │ (None, 1, 1,      │          0 │ block6d_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_expand   │ (None, 1, 1,      │     56,448 │ block6d_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_excite   │ (None, 10, 10,    │          0 │ block6d_activati… │
# │ (Multiply)          │ 1152)             │            │ block6d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_project_co… │ (None, 10, 10,    │    221,184 │ block6d_se_excit… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_project_bn  │ (None, 10, 10,    │        768 │ block6d_project_… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_drop        │ (None, 10, 10,    │          0 │ block6d_project_… │
# │ (Dropout)           │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_add (Add)   │ (None, 10, 10,    │          0 │ block6d_drop[0][… │
# │                     │ 192)              │            │ block6c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_conv │ (None, 10, 10,    │    221,184 │ block6d_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_bn   │ (None, 10, 10,    │      4,608 │ block7a_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_act… │ (None, 10, 10,    │          0 │ block7a_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_dwconv      │ (None, 10, 10,    │     10,368 │ block7a_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_bn          │ (None, 10, 10,    │      4,608 │ block7a_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_activation  │ (None, 10, 10,    │          0 │ block7a_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_squeeze  │ (None, 1152)      │          0 │ block7a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reshape  │ (None, 1, 1,      │          0 │ block7a_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block7a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_expand   │ (None, 1, 1,      │     56,448 │ block7a_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_excite   │ (None, 10, 10,    │          0 │ block7a_activati… │
# │ (Multiply)          │ 1152)             │            │ block7a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_co… │ (None, 10, 10,    │    368,640 │ block7a_se_excit… │
# │ (Conv2D)            │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_bn  │ (None, 10, 10,    │      1,280 │ block7a_project_… │
# │ (BatchNormalizatio… │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_conv (Conv2D)   │ (None, 10, 10,    │    409,600 │ block7a_project_… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_bn              │ (None, 10, 10,    │      5,120 │ top_conv[0][0]    │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_activation      │ (None, 10, 10,    │          0 │ top_bn[0][0]      │
# │ (Activation)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ top_activation[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    163,968 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 10)        │      1,290 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,214,829 (16.08 MB)
#  Trainable params: 4,172,806 (15.92 MB)
#  Non-trainable params: 42,023 (164.16 KB)

# %% [markdown]
# # k=1

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Musical Genre Classification/Database/genre_specscal_mel_kfold/treinamento1.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "training1")
VAL_DATASET = os.path.join("/content", "validation1")
#TEST_DATASET = os.path.join("/content", "teste1")
#METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(VAL_DATASET) #10 classes
classes = sorted(classes)


def make_dataset(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.resize(image, (300, 300))  # resize para modelos pré-treinados
        image = preprocess_input(image)  # 👈 importante
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    class_names = sorted(os.listdir(path))  # Agora local
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [class_names.index(name.split('/')[-2]) for name in filenames]

    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds, class_names, images_ds, labels_ds

# %%
def make_dataset_predict(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.resize(image, (300, 300))  # resize para modelos pré-treinados
        image = preprocess_input(image)  # 👈 importante
        return image

    def configure_for_performance(ds):
        #ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        #ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    class_names = sorted(os.listdir(path))  # Agora local
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [class_names.index(name.split('/')[-2]) for name in filenames]

    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds, class_names, images_ds, labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset(TRAIN_DATASET, BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_predict(VAL_DATASET, BS) #labels com valores 0 a 234
#testDS, classes_te, images_test, labels_test = make_dataset(TEST_DATASET, BS)
print(trainDS)
print(validationDS)
#print(testDS)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_augmentation(path, batch_size):
    def parse_image_with_stretch_tf(filename, label):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)

        # Stretch horizontal
        stretch_factors = tf.constant([1, 1.1, 1.2, 1.3], dtype=tf.float32)
        idx = tf.random.uniform([], minval=0, maxval=3, dtype=tf.int32)
        stretch = stretch_factors[idx]

        height = tf.shape(image)[0]
        width = tf.cast(tf.shape(image)[1], tf.float32)
        new_width = tf.cast(width * stretch, tf.int32)

        image = tf.image.resize(image, size=[height, new_width])
        image = tf.image.resize_with_crop_or_pad(image, 300, 300)
        image = preprocess_input(image)  # 👈 importante

        # Define forma estática para o grafo entender
        image.set_shape([300, 300, 3])
        return image, label

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(tf.data.AUTOTUNE)
        return ds

    # Carrega nomes e rótulos
    class_names = sorted(os.listdir(path))
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [class_names.index(name.split('/')[-2]) for name in filenames]

    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)

    # Unifica imagens e rótulos ANTES do map
    ds = tf.data.Dataset.zip((filenames_ds, labels_ds))
    ds = ds.map(parse_image_with_stretch_tf, num_parallel_calls=tf.data.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds, class_names

# %%
trainDS_aug, classes_t_aug = make_dataset_augmentation(TRAIN_DATASET, BS) #labels com valores 0 a 234
print(trainDS_aug)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(classes_t)
print(classes_t_aug)
print(classes)
# Out:
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
#list_images_train_aug = list(images_train_aug.as_numpy_iterator())

# %%
#list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
#labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257

list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
#labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

#list_labels_test= list(labels_test.as_numpy_iterator())
#labels_test_true = []
#for i in list_labels_test:
#       labels_test_true.append(classes[i])
#labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
#images_test_ds = np.array(list_images_test)
print(len(labels_train_true))
print(len(labels_validation_true))
#print(labels_test_true.shape)
print(trainDS_aug)
print(trainDS)
print(validationDS)
#print(testDS)
# Out:
# (800, 300, 300, 3)
# (200, 300, 300, 3)
# 800
# 200
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1].shape)
# Out:
# (300, 300, 3)

# %%
#print(list_images_train_aug[1].shape)

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/BS)
validation_steps = math.ceil(num_images_val/BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)
optimizer = keras.optimizers.Adam(learning_rate=1e-4)


base_model.trainable = True
for layer in base_model.layers[:-80]:
    layer.trainable = False

model.compile(loss ='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS_aug, validation_data=validationDS, epochs=100, batch_size=BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1)
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 52s 551ms/step - accuracy: 0.1976 - loss: 2.2422 - val_accuracy: 0.1350 - val_loss: 2.2982
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.4434 - loss: 1.8184 - val_accuracy: 0.2100 - val_loss: 2.1863
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.5458 - loss: 1.4940 - val_accuracy: 0.2450 - val_loss: 2.0439
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.6421 - loss: 1.2462 - val_accuracy: 0.3700 - val_loss: 1.8299
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.7122 - loss: 0.9746 - val_accuracy: 0.4850 - val_loss: 1.5895
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.7687 - loss: 0.8450 - val_accuracy: 0.5700 - val_loss: 1.3726
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.7745 - loss: 0.7124 - val_accuracy: 0.6100 - val_loss: 1.1983
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8295 - loss: 0.6262 - val_accuracy: 0.6200 - val_loss: 1.0479
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8291 - loss: 0.5688 - val_accuracy: 0.6450 - val_loss: 0.9950
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8836 - loss: 0.4432 - val_accuracy: 0.6650 - val_loss: 0.8751
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8873 - loss: 0.4054 - val_accuracy: 0.6700 - val_loss: 0.8912
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8893 - loss: 0.3683 - val_accuracy: 0.6900 - val_loss: 0.8039
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.9238 - loss: 0.3088 - val_accuracy: 0.7250 - val_loss: 0.7986
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9061 - loss: 0.3009 - val_accuracy: 0.6950 - val_loss: 0.7609
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.9216 - loss: 0.2907 - val_accuracy: 0.7350 - val_loss: 0.7739
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.9301 - loss: 0.2402 - val_accuracy: 0.7250 - val_loss: 0.7854
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9567 - loss: 0.1718 - val_accuracy: 0.7550 - val_loss: 0.7714
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9503 - loss: 0.1748 - val_accuracy: 0.7500 - val_loss: 0.7739
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9448 - loss: 0.1718 - val_accuracy: 0.7350 - val_loss: 0.8011
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9665 - loss: 0.1424 - val_accuracy: 0.7150 - val_loss: 0.8603
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9591 - loss: 0.1338 - val_accuracy: 0.7650 - val_loss: 0.8439
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9824 - loss: 0.1049 - val_accuracy: 0.7550 - val_loss: 0.8140
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9457 - loss: 0.1438 - val_accuracy: 0.7550 - val_loss: 0.7515
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9505 - loss: 0.1488 - val_accuracy: 0.7450 - val_loss: 0.8641
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9729 - loss: 0.0897 - val_accuracy: 0.7750 - val_loss: 0.7828
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9745 - loss: 0.0868 - val_accuracy: 0.7650 - val_loss: 0.8296
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9703 - loss: 0.1130 - val_accuracy: 0.7700 - val_loss: 0.7825
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9813 - loss: 0.0879 - val_accuracy: 0.7850 - val_loss: 0.7772
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9784 - loss: 0.0810 - val_accuracy: 0.7650 - val_loss: 0.8155
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9713 - loss: 0.0958 - val_accuracy: 0.8050 - val_loss: 0.8732
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9856 - loss: 0.0604 - val_accuracy: 0.7750 - val_loss: 0.8636
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9866 - loss: 0.0663 - val_accuracy: 0.7700 - val_loss: 0.8567
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9809 - loss: 0.0634 - val_accuracy: 0.7550 - val_loss: 0.9121
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9793 - loss: 0.0849 - val_accuracy: 0.7550 - val_loss: 0.8595
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9857 - loss: 0.0661 - val_accuracy: 0.7750 - val_loss: 0.8763
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9878 - loss: 0.0546 - val_accuracy: 0.7900 - val_loss: 0.8254
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9923 - loss: 0.0456 - val_accuracy: 0.7750 - val_loss: 0.8184
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9747 - loss: 0.0939 - val_accuracy: 0.7800 - val_loss: 0.9447
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9909 - loss: 0.0470 - val_accuracy: 0.7800 - val_loss: 0.9003
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9898 - loss: 0.0444 - val_accuracy: 0.8050 - val_loss: 0.8579
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9902 - loss: 0.0419 - val_accuracy: 0.7550 - val_loss: 0.8397
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9812 - loss: 0.0653 - val_accuracy: 0.7850 - val_loss: 0.8726
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9844 - loss: 0.0583 - val_accuracy: 0.8050 - val_loss: 0.8732
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9840 - loss: 0.0611 - val_accuracy: 0.8050 - val_loss: 0.8559
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9913 - loss: 0.0345 - val_accuracy: 0.7750 - val_loss: 0.8579
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9870 - loss: 0.0504 - val_accuracy: 0.7650 - val_loss: 0.9167
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9936 - loss: 0.0371 - val_accuracy: 0.7700 - val_loss: 0.9071
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9947 - loss: 0.0321 - val_accuracy: 0.7650 - val_loss: 0.9024
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9872 - loss: 0.0551 - val_accuracy: 0.7550 - val_loss: 0.9315
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9910 - loss: 0.0460 - val_accuracy: 0.7600 - val_loss: 1.0186
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9900 - loss: 0.0408 - val_accuracy: 0.7650 - val_loss: 0.9034
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9913 - loss: 0.0410 - val_accuracy: 0.7700 - val_loss: 0.9061
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9889 - loss: 0.0310 - val_accuracy: 0.7700 - val_loss: 0.9079
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9851 - loss: 0.0525 - val_accuracy: 0.7700 - val_loss: 0.9012
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9912 - loss: 0.0305 - val_accuracy: 0.7800 - val_loss: 0.9266
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9954 - loss: 0.0213 - val_accuracy: 0.7650 - val_loss: 0.9211
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9905 - loss: 0.0308 - val_accuracy: 0.7750 - val_loss: 0.9468
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9825 - loss: 0.0495 - val_accuracy: 0.7950 - val_loss: 0.9486
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9887 - loss: 0.0348 - val_accuracy: 0.7600 - val_loss: 0.9496
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9898 - loss: 0.0395 - val_accuracy: 0.7950 - val_loss: 0.8776
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9877 - loss: 0.0446 - val_accuracy: 0.7500 - val_loss: 0.9735
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9920 - loss: 0.0288 - val_accuracy: 0.7650 - val_loss: 0.8857
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9961 - loss: 0.0233 - val_accuracy: 0.7800 - val_loss: 0.9071
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9913 - loss: 0.0221 - val_accuracy: 0.7850 - val_loss: 0.8927
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9963 - loss: 0.0265 - val_accuracy: 0.7850 - val_loss: 0.8862
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9901 - loss: 0.0468 - val_accuracy: 0.8000 - val_loss: 0.8956
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9873 - loss: 0.0375 - val_accuracy: 0.7900 - val_loss: 1.0087
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9974 - loss: 0.0174 - val_accuracy: 0.7950 - val_loss: 1.0564
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9875 - loss: 0.0364 - val_accuracy: 0.7850 - val_loss: 1.0502
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9958 - loss: 0.0232 - val_accuracy: 0.8050 - val_loss: 1.0266
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9905 - loss: 0.0285 - val_accuracy: 0.7750 - val_loss: 0.9527
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9925 - loss: 0.0292 - val_accuracy: 0.7850 - val_loss: 0.9741
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9983 - loss: 0.0145 - val_accuracy: 0.7700 - val_loss: 1.0055
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9952 - loss: 0.0252 - val_accuracy: 0.7750 - val_loss: 1.0294
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9959 - loss: 0.0213 - val_accuracy: 0.7800 - val_loss: 1.0535
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9981 - loss: 0.0098 - val_accuracy: 0.7550 - val_loss: 1.0445
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9915 - loss: 0.0270 - val_accuracy: 0.7750 - val_loss: 0.9746
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9934 - loss: 0.0231 - val_accuracy: 0.7700 - val_loss: 0.9643
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9935 - loss: 0.0211 - val_accuracy: 0.7800 - val_loss: 0.9581
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9971 - loss: 0.0176 - val_accuracy: 0.7550 - val_loss: 1.0870
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9928 - loss: 0.0204 - val_accuracy: 0.7400 - val_loss: 1.1928
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9941 - loss: 0.0214 - val_accuracy: 0.7600 - val_loss: 1.0987
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9934 - loss: 0.0391 - val_accuracy: 0.7750 - val_loss: 1.0924
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9888 - loss: 0.0307 - val_accuracy: 0.7800 - val_loss: 1.1311
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9967 - loss: 0.0123 - val_accuracy: 0.7850 - val_loss: 1.0897
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9875 - loss: 0.0305 - val_accuracy: 0.7900 - val_loss: 1.0438
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9896 - loss: 0.0255 - val_accuracy: 0.7800 - val_loss: 1.0089
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9980 - loss: 0.0136 - val_accuracy: 0.7550 - val_loss: 0.9876
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9932 - loss: 0.0218 - val_accuracy: 0.7950 - val_loss: 1.0160
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9903 - loss: 0.0380 - val_accuracy: 0.7800 - val_loss: 1.0251
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9957 - loss: 0.0234 - val_accuracy: 0.7800 - val_loss: 1.0019
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9921 - loss: 0.0205 - val_accuracy: 0.7700 - val_loss: 1.0549
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9952 - loss: 0.0177 - val_accuracy: 0.8050 - val_loss: 1.0112
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9944 - loss: 0.0216 - val_accuracy: 0.7800 - val_loss: 0.9269
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9957 - loss: 0.0202 - val_accuracy: 0.7600 - val_loss: 1.0950
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9929 - loss: 0.0175 - val_accuracy: 0.7750 - val_loss: 1.0287
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9901 - loss: 0.0307 - val_accuracy: 0.7900 - val_loss: 0.9932
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9985 - loss: 0.0104 - val_accuracy: 0.8300 - val_loss: 0.8871
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9935 - loss: 0.0163 - val_accuracy: 0.8100 - val_loss: 0.9066
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9908 - loss: 0.0254 - val_accuracy: 0.7800 - val_loss: 0.9543
# CPU times: user 5min 11s, sys: 1min 40s, total: 6min 52s
# Wall time: 5min 15s

# %%
# Fase 2: Fine-tuning (descongelar parte da base)
base_model.trainable = True

# Congela camadas iniciais e libera só as últimas 20, por exemplo:
#for layer in base_model.layers[:-50]:
#    layer.trainable = False

model.optimizer.learning_rate.assign(1e-5)

#keras.backend.set_value(model.optimizer.learning_rate, 1e-5)

#from tensorflow.keras.optimizers import Adam

#model.compile(optimizer=Adam(1e-5), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Compila com taxa de aprendizado reduzida
#model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-5), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history_finetune = model.fit(trainDS_aug, validation_data=validationDS, epochs=20, batch_size=BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1)
# Out:
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9972 - loss: 0.0104 - val_accuracy: 0.7850 - val_loss: 0.9252
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9958 - loss: 0.0107 - val_accuracy: 0.7700 - val_loss: 0.9197
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9999 - loss: 0.0067 - val_accuracy: 0.7750 - val_loss: 0.9192
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9972 - loss: 0.0110 - val_accuracy: 0.7750 - val_loss: 0.9092
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9945 - loss: 0.0196 - val_accuracy: 0.7750 - val_loss: 0.8996
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9989 - loss: 0.0126 - val_accuracy: 0.7750 - val_loss: 0.9021
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9989 - loss: 0.0063 - val_accuracy: 0.7800 - val_loss: 0.8988
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9963 - loss: 0.0130 - val_accuracy: 0.7800 - val_loss: 0.8952
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9928 - loss: 0.0181 - val_accuracy: 0.7750 - val_loss: 0.8990
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9976 - loss: 0.0142 - val_accuracy: 0.7750 - val_loss: 0.8951
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9995 - loss: 0.0097 - val_accuracy: 0.7750 - val_loss: 0.8957
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9933 - loss: 0.0264 - val_accuracy: 0.7750 - val_loss: 0.8903
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9946 - loss: 0.0274 - val_accuracy: 0.7850 - val_loss: 0.8971
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9988 - loss: 0.0094 - val_accuracy: 0.7850 - val_loss: 0.9013
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9997 - loss: 0.0119 - val_accuracy: 0.7850 - val_loss: 0.8974
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9972 - loss: 0.0071 - val_accuracy: 0.7850 - val_loss: 0.9028
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9996 - loss: 0.0074 - val_accuracy: 0.7850 - val_loss: 0.8990
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9962 - loss: 0.0088 - val_accuracy: 0.7850 - val_loss: 0.8953
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9984 - loss: 0.0061 - val_accuracy: 0.7850 - val_loss: 0.9002
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9882 - loss: 0.0198 - val_accuracy: 0.7850 - val_loss: 0.9105

# %%
acc_phase1 = history.history['accuracy']
val_acc_phase1 = history.history['val_accuracy']

acc_phase2 = history_finetune.history['accuracy']
val_acc_phase2 = history_finetune.history['val_accuracy']

acc_total = acc_phase1 + acc_phase2
val_acc_total = val_acc_phase1 + val_acc_phase2
epochs_total = range(len(acc_total))

plt.figure(figsize=(6,5))
plt.plot(epochs_total, acc_total, label='Training Accuracy')
plt.plot(epochs_total, val_acc_total, label='Validation Accuracy')

# Mark the transition between phases
plt.axvline(x=len(acc_phase1)-1, color='gray', linestyle='--', label='Start of Fine-Tuning')

plt.title('Accuracy - Training and Validation - k1')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/accuracy_genre_mel_k1.pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/acc_total_k1.npy', acc_total)
np.save('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/val_acc_total_k1.npy', val_acc_total)

# %%
model.save('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/model_k1.keras')

# %%
model = keras.models.load_model('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/model_k1.keras')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 112 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

testDS_eval = validationDS.unbatch().batch(32)  # ou validationDS

y_true = []
y_pred = []

for images, labels in testDS_eval:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(labels.numpy())

cm = confusion_matrix(y_true, y_pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step

# %%
# Supondo que você tem class_names do seu dataset
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix - k1")
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/confusionmatrix_genre_mel_k1.pdf')
plt.show()

# %%
from google.colab import runtime
runtime.unassign()

# %% [markdown]
# # k=2

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Musical Genre Classification/Database/genre_specscal_mel_kfold/treinamento2.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "training2")
VAL_DATASET = os.path.join("/content", "validation2")
#TEST_DATASET = os.path.join("/content", "teste1")
#METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(VAL_DATASET) #10 classes
classes = sorted(classes)


def make_dataset(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.resize(image, (300, 300))  # resize para modelos pré-treinados
        image = preprocess_input(image)  # 👈 importante
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    class_names = sorted(os.listdir(path))  # Agora local
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [class_names.index(name.split('/')[-2]) for name in filenames]

    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds, class_names, images_ds, labels_ds

# %%
def make_dataset_predict(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.resize(image, (300, 300))  # resize para modelos pré-treinados
        image = preprocess_input(image)  # 👈 importante
        return image

    def configure_for_performance(ds):
        #ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        #ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    class_names = sorted(os.listdir(path))  # Agora local
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [class_names.index(name.split('/')[-2]) for name in filenames]

    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds, class_names, images_ds, labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset(TRAIN_DATASET, BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_predict(VAL_DATASET, BS) #labels com valores 0 a 234
#testDS, classes_te, images_test, labels_test = make_dataset(TEST_DATASET, BS)
print(trainDS)
print(validationDS)
#print(testDS)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_augmentation(path, batch_size):
    def parse_image_with_stretch_tf(filename, label):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)

        # Stretch horizontal
        stretch_factors = tf.constant([1, 1.1, 1.2, 1.3], dtype=tf.float32)
        idx = tf.random.uniform([], minval=0, maxval=3, dtype=tf.int32)
        stretch = stretch_factors[idx]

        height = tf.shape(image)[0]
        width = tf.cast(tf.shape(image)[1], tf.float32)
        new_width = tf.cast(width * stretch, tf.int32)

        image = tf.image.resize(image, size=[height, new_width])
        image = tf.image.resize_with_crop_or_pad(image, 300, 300)
        image = preprocess_input(image)  # 👈 importante

        # Define forma estática para o grafo entender
        image.set_shape([300, 300, 3])
        return image, label

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(tf.data.AUTOTUNE)
        return ds

    # Carrega nomes e rótulos
    class_names = sorted(os.listdir(path))
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [class_names.index(name.split('/')[-2]) for name in filenames]

    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)

    # Unifica imagens e rótulos ANTES do map
    ds = tf.data.Dataset.zip((filenames_ds, labels_ds))
    ds = ds.map(parse_image_with_stretch_tf, num_parallel_calls=tf.data.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds, class_names

# %%
trainDS_aug, classes_t_aug = make_dataset_augmentation(TRAIN_DATASET, BS) #labels com valores 0 a 234
print(trainDS_aug)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(classes_t)
print(classes_t_aug)
print(classes)
# Out:
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
#list_images_train_aug = list(images_train_aug.as_numpy_iterator())

# %%
#list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
#labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257

list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
#labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

#list_labels_test= list(labels_test.as_numpy_iterator())
#labels_test_true = []
#for i in list_labels_test:
#       labels_test_true.append(classes[i])
#labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
#images_test_ds = np.array(list_images_test)
print(len(labels_train_true))
print(len(labels_validation_true))
#print(labels_test_true.shape)
print(trainDS_aug)
print(trainDS)
print(validationDS)
#print(testDS)
# Out:
# (800, 300, 300, 3)
# (200, 300, 300, 3)
# 800
# 200
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1].shape)
# Out:
# (300, 300, 3)

# %%
#print(list_images_train_aug[1].shape)

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/BS)
validation_steps = math.ceil(num_images_val/BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)
optimizer = keras.optimizers.Adam(learning_rate=1e-4)


base_model.trainable = True
for layer in base_model.layers[:-80]:
    layer.trainable = False

model.compile(loss ='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS_aug, validation_data=validationDS, epochs=100, batch_size=BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1)
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 53s 554ms/step - accuracy: 0.1679 - loss: 2.2468 - val_accuracy: 0.1350 - val_loss: 2.2737
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.4716 - loss: 1.7883 - val_accuracy: 0.1900 - val_loss: 2.1588
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.5782 - loss: 1.4526 - val_accuracy: 0.3150 - val_loss: 1.9946
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.6474 - loss: 1.1672 - val_accuracy: 0.3150 - val_loss: 1.8225
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.6904 - loss: 1.0057 - val_accuracy: 0.3500 - val_loss: 1.7162
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.7535 - loss: 0.8130 - val_accuracy: 0.4250 - val_loss: 1.6111
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.7724 - loss: 0.7143 - val_accuracy: 0.4400 - val_loss: 1.4635
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.8289 - loss: 0.6019 - val_accuracy: 0.5250 - val_loss: 1.2585
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.8354 - loss: 0.5486 - val_accuracy: 0.6200 - val_loss: 1.1043
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.8414 - loss: 0.4980 - val_accuracy: 0.6700 - val_loss: 0.9133
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.8975 - loss: 0.3657 - val_accuracy: 0.6700 - val_loss: 0.9228
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.8908 - loss: 0.3549 - val_accuracy: 0.6900 - val_loss: 0.8580
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9386 - loss: 0.3224 - val_accuracy: 0.7500 - val_loss: 0.8606
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9183 - loss: 0.2704 - val_accuracy: 0.6800 - val_loss: 0.9481
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9359 - loss: 0.2304 - val_accuracy: 0.7500 - val_loss: 0.8476
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9333 - loss: 0.2446 - val_accuracy: 0.7650 - val_loss: 0.8439
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9409 - loss: 0.2167 - val_accuracy: 0.7350 - val_loss: 0.8681
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9513 - loss: 0.1789 - val_accuracy: 0.7400 - val_loss: 0.8306
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9483 - loss: 0.1966 - val_accuracy: 0.7650 - val_loss: 0.8231
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9451 - loss: 0.1828 - val_accuracy: 0.7450 - val_loss: 0.8210
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9823 - loss: 0.1201 - val_accuracy: 0.7800 - val_loss: 0.8109
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.9649 - loss: 0.1373 - val_accuracy: 0.7700 - val_loss: 0.8756
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.9689 - loss: 0.1069 - val_accuracy: 0.7650 - val_loss: 0.9247
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.9778 - loss: 0.1131 - val_accuracy: 0.7750 - val_loss: 0.8988
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.9873 - loss: 0.0656 - val_accuracy: 0.7550 - val_loss: 0.9385
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.9755 - loss: 0.0997 - val_accuracy: 0.7850 - val_loss: 0.9313
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.9625 - loss: 0.1034 - val_accuracy: 0.7750 - val_loss: 0.9175
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.9731 - loss: 0.1106 - val_accuracy: 0.7750 - val_loss: 0.8706
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.9771 - loss: 0.0766 - val_accuracy: 0.7800 - val_loss: 0.8971
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.9794 - loss: 0.0692 - val_accuracy: 0.7650 - val_loss: 0.9383
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.9911 - loss: 0.0481 - val_accuracy: 0.7650 - val_loss: 0.8866
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.9779 - loss: 0.0807 - val_accuracy: 0.7550 - val_loss: 0.9607
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.9888 - loss: 0.0593 - val_accuracy: 0.7700 - val_loss: 0.9085
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.9827 - loss: 0.0483 - val_accuracy: 0.7700 - val_loss: 0.9217
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.9880 - loss: 0.0738 - val_accuracy: 0.7750 - val_loss: 0.8891
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.9872 - loss: 0.0645 - val_accuracy: 0.7700 - val_loss: 0.9035
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9894 - loss: 0.0575 - val_accuracy: 0.7300 - val_loss: 1.0094
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9828 - loss: 0.0672 - val_accuracy: 0.7550 - val_loss: 0.9563
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.9865 - loss: 0.0429 - val_accuracy: 0.7650 - val_loss: 1.0079
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9918 - loss: 0.0471 - val_accuracy: 0.7550 - val_loss: 0.9144
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9843 - loss: 0.0590 - val_accuracy: 0.7650 - val_loss: 0.9157
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9808 - loss: 0.0696 - val_accuracy: 0.7700 - val_loss: 0.9648
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9874 - loss: 0.0397 - val_accuracy: 0.7750 - val_loss: 0.8714
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9776 - loss: 0.0610 - val_accuracy: 0.7550 - val_loss: 1.0170
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9882 - loss: 0.0575 - val_accuracy: 0.7900 - val_loss: 0.9457
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9956 - loss: 0.0250 - val_accuracy: 0.7850 - val_loss: 0.9225
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9912 - loss: 0.0362 - val_accuracy: 0.7750 - val_loss: 1.0009
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9870 - loss: 0.0347 - val_accuracy: 0.7950 - val_loss: 0.9761
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9907 - loss: 0.0291 - val_accuracy: 0.7750 - val_loss: 1.0198
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9844 - loss: 0.0453 - val_accuracy: 0.7650 - val_loss: 1.0519
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9797 - loss: 0.0646 - val_accuracy: 0.7750 - val_loss: 0.9759
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9803 - loss: 0.0515 - val_accuracy: 0.7750 - val_loss: 1.0077
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9906 - loss: 0.0375 - val_accuracy: 0.7650 - val_loss: 1.0768
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9888 - loss: 0.0355 - val_accuracy: 0.7800 - val_loss: 0.9702
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9887 - loss: 0.0324 - val_accuracy: 0.7600 - val_loss: 1.0052
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9806 - loss: 0.0660 - val_accuracy: 0.7550 - val_loss: 1.0055
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9853 - loss: 0.0381 - val_accuracy: 0.7900 - val_loss: 0.9422
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9877 - loss: 0.0504 - val_accuracy: 0.7750 - val_loss: 0.9223
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9870 - loss: 0.0416 - val_accuracy: 0.7600 - val_loss: 0.9418
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9915 - loss: 0.0306 - val_accuracy: 0.7900 - val_loss: 0.9815
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.9904 - loss: 0.0329 - val_accuracy: 0.7900 - val_loss: 0.9974
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.9910 - loss: 0.0333 - val_accuracy: 0.7950 - val_loss: 1.0273
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9855 - loss: 0.0436 - val_accuracy: 0.7900 - val_loss: 1.0355
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9893 - loss: 0.0400 - val_accuracy: 0.7700 - val_loss: 1.0567
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9885 - loss: 0.0375 - val_accuracy: 0.7650 - val_loss: 1.0333
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9828 - loss: 0.0402 - val_accuracy: 0.7650 - val_loss: 0.9797
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9945 - loss: 0.0321 - val_accuracy: 0.7800 - val_loss: 0.9892
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9916 - loss: 0.0238 - val_accuracy: 0.7700 - val_loss: 1.0179
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.9955 - loss: 0.0268 - val_accuracy: 0.7650 - val_loss: 1.0467
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9917 - loss: 0.0277 - val_accuracy: 0.7650 - val_loss: 1.0338
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9911 - loss: 0.0257 - val_accuracy: 0.7650 - val_loss: 1.0342
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9832 - loss: 0.0437 - val_accuracy: 0.7700 - val_loss: 1.0619
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9873 - loss: 0.0329 - val_accuracy: 0.7800 - val_loss: 1.0214
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9909 - loss: 0.0271 - val_accuracy: 0.7750 - val_loss: 1.0339
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9888 - loss: 0.0420 - val_accuracy: 0.7550 - val_loss: 1.0398
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9895 - loss: 0.0402 - val_accuracy: 0.7500 - val_loss: 1.1516
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9906 - loss: 0.0306 - val_accuracy: 0.7700 - val_loss: 1.1192
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9911 - loss: 0.0204 - val_accuracy: 0.7700 - val_loss: 1.1401
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9935 - loss: 0.0239 - val_accuracy: 0.7450 - val_loss: 1.2457
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9956 - loss: 0.0286 - val_accuracy: 0.7600 - val_loss: 1.1348
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9897 - loss: 0.0194 - val_accuracy: 0.7650 - val_loss: 1.1941
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9967 - loss: 0.0151 - val_accuracy: 0.7650 - val_loss: 1.1714
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9936 - loss: 0.0233 - val_accuracy: 0.7700 - val_loss: 1.0080
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9938 - loss: 0.0264 - val_accuracy: 0.7900 - val_loss: 0.9367
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9904 - loss: 0.0256 - val_accuracy: 0.7700 - val_loss: 1.0104
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9981 - loss: 0.0166 - val_accuracy: 0.7750 - val_loss: 0.9960
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9857 - loss: 0.0458 - val_accuracy: 0.7650 - val_loss: 1.0478
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9993 - loss: 0.0130 - val_accuracy: 0.7650 - val_loss: 1.0975
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9957 - loss: 0.0278 - val_accuracy: 0.7700 - val_loss: 1.1130
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9985 - loss: 0.0161 - val_accuracy: 0.7600 - val_loss: 1.2008
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9918 - loss: 0.0175 - val_accuracy: 0.7350 - val_loss: 1.2155
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9897 - loss: 0.0235 - val_accuracy: 0.7400 - val_loss: 1.1647
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9971 - loss: 0.0184 - val_accuracy: 0.7650 - val_loss: 1.1527
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9926 - loss: 0.0189 - val_accuracy: 0.7800 - val_loss: 1.1168
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9889 - loss: 0.0273 - val_accuracy: 0.7500 - val_loss: 1.0777
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9929 - loss: 0.0196 - val_accuracy: 0.7700 - val_loss: 1.0476
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.9944 - loss: 0.0188 - val_accuracy: 0.7550 - val_loss: 1.0645
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9933 - loss: 0.0212 - val_accuracy: 0.7900 - val_loss: 1.0524
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9931 - loss: 0.0224 - val_accuracy: 0.7750 - val_loss: 1.0924
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9916 - loss: 0.0243 - val_accuracy: 0.7900 - val_loss: 1.1359
# CPU times: user 5min 19s, sys: 1min 44s, total: 7min 3s
# Wall time: 5min 25s

# %%
# Fase 2: Fine-tuning (descongelar parte da base)
base_model.trainable = True

# Congela camadas iniciais e libera só as últimas 20, por exemplo:
#for layer in base_model.layers[:-50]:
#    layer.trainable = False

model.optimizer.learning_rate.assign(1e-5)

#keras.backend.set_value(model.optimizer.learning_rate, 1e-5)

#from tensorflow.keras.optimizers import Adam

#model.compile(optimizer=Adam(1e-5), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Compila com taxa de aprendizado reduzida
#model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-5), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history_finetune = model.fit(trainDS_aug, validation_data=validationDS, epochs=20, batch_size=BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1)
# Out:
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.9934 - loss: 0.0195 - val_accuracy: 0.7850 - val_loss: 1.1251
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9872 - loss: 0.0303 - val_accuracy: 0.7950 - val_loss: 1.1087
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9934 - loss: 0.0230 - val_accuracy: 0.7950 - val_loss: 1.1008
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9980 - loss: 0.0141 - val_accuracy: 0.7950 - val_loss: 1.0917
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9888 - loss: 0.0212 - val_accuracy: 0.7950 - val_loss: 1.0878
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9959 - loss: 0.0155 - val_accuracy: 0.7950 - val_loss: 1.0856
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9940 - loss: 0.0195 - val_accuracy: 0.8000 - val_loss: 1.0764
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9946 - loss: 0.0135 - val_accuracy: 0.8000 - val_loss: 1.0745
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9986 - loss: 0.0090 - val_accuracy: 0.7950 - val_loss: 1.0748
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9969 - loss: 0.0102 - val_accuracy: 0.7950 - val_loss: 1.0717
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9958 - loss: 0.0161 - val_accuracy: 0.7950 - val_loss: 1.0681
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9927 - loss: 0.0151 - val_accuracy: 0.7950 - val_loss: 1.0657
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9972 - loss: 0.0142 - val_accuracy: 0.7900 - val_loss: 1.0750
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9919 - loss: 0.0336 - val_accuracy: 0.7900 - val_loss: 1.0784
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9904 - loss: 0.0182 - val_accuracy: 0.7900 - val_loss: 1.0684
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9888 - loss: 0.0199 - val_accuracy: 0.7900 - val_loss: 1.0640
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.9941 - loss: 0.0190 - val_accuracy: 0.7900 - val_loss: 1.0644
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9975 - loss: 0.0097 - val_accuracy: 0.7900 - val_loss: 1.0605
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.9976 - loss: 0.0073 - val_accuracy: 0.7900 - val_loss: 1.0578
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9987 - loss: 0.0120 - val_accuracy: 0.7900 - val_loss: 1.0588

# %%
acc_phase1 = history.history['accuracy']
val_acc_phase1 = history.history['val_accuracy']

acc_phase2 = history_finetune.history['accuracy']
val_acc_phase2 = history_finetune.history['val_accuracy']

acc_total = acc_phase1 + acc_phase2
val_acc_total = val_acc_phase1 + val_acc_phase2
epochs_total = range(len(acc_total))

plt.figure(figsize=(6,5))
plt.plot(epochs_total, acc_total, label='Training Accuracy')
plt.plot(epochs_total, val_acc_total, label='Validation Accuracy')

# Mark the transition between phases
plt.axvline(x=len(acc_phase1)-1, color='gray', linestyle='--', label='Start of Fine-Tuning')

plt.title('Accuracy - Training and Validation - k2')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/accuracy_genre_mel_k2.pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/acc_total_k2.npy', acc_total)
np.save('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/val_acc_total_k2.npy', val_acc_total)

# %%
model.save('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/model_k2.keras')

# %%
model = keras.models.load_model('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/model_k2.keras')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 112 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

testDS_eval = validationDS.unbatch().batch(32)  # ou validationDS

y_true = []
y_pred = []

for images, labels in testDS_eval:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(labels.numpy())

cm = confusion_matrix(y_true, y_pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step

# %%
# Supondo que você tem class_names do seu dataset
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix - k2")
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/confusionmatrix_genre_mel_k2.pdf')
plt.show()

# %%
from google.colab import runtime
runtime.unassign()

# %% [markdown]
# # k=3

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Musical Genre Classification/Database/genre_specscal_mel_kfold/treinamento3.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "training3")
VAL_DATASET = os.path.join("/content", "validation3")
#TEST_DATASET = os.path.join("/content", "teste1")
#METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(VAL_DATASET) #10 classes
classes = sorted(classes)


def make_dataset(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.resize(image, (300, 300))  # resize para modelos pré-treinados
        image = preprocess_input(image)  # 👈 importante
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    class_names = sorted(os.listdir(path))  # Agora local
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [class_names.index(name.split('/')[-2]) for name in filenames]

    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds, class_names, images_ds, labels_ds

# %%
def make_dataset_predict(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.resize(image, (300, 300))  # resize para modelos pré-treinados
        image = preprocess_input(image)  # 👈 importante
        return image

    def configure_for_performance(ds):
        #ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        #ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    class_names = sorted(os.listdir(path))  # Agora local
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [class_names.index(name.split('/')[-2]) for name in filenames]

    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds, class_names, images_ds, labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset(TRAIN_DATASET, BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_predict(VAL_DATASET, BS) #labels com valores 0 a 234
#testDS, classes_te, images_test, labels_test = make_dataset(TEST_DATASET, BS)
print(trainDS)
print(validationDS)
#print(testDS)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_augmentation(path, batch_size):
    def parse_image_with_stretch_tf(filename, label):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)

        # Stretch horizontal
        stretch_factors = tf.constant([1, 1.1, 1.2, 1.3], dtype=tf.float32)
        idx = tf.random.uniform([], minval=0, maxval=3, dtype=tf.int32)
        stretch = stretch_factors[idx]

        height = tf.shape(image)[0]
        width = tf.cast(tf.shape(image)[1], tf.float32)
        new_width = tf.cast(width * stretch, tf.int32)

        image = tf.image.resize(image, size=[height, new_width])
        image = tf.image.resize_with_crop_or_pad(image, 300, 300)
        image = preprocess_input(image)  # 👈 importante

        # Define forma estática para o grafo entender
        image.set_shape([300, 300, 3])
        return image, label

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(tf.data.AUTOTUNE)
        return ds

    # Carrega nomes e rótulos
    class_names = sorted(os.listdir(path))
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [class_names.index(name.split('/')[-2]) for name in filenames]

    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)

    # Unifica imagens e rótulos ANTES do map
    ds = tf.data.Dataset.zip((filenames_ds, labels_ds))
    ds = ds.map(parse_image_with_stretch_tf, num_parallel_calls=tf.data.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds, class_names

# %%
trainDS_aug, classes_t_aug = make_dataset_augmentation(TRAIN_DATASET, BS) #labels com valores 0 a 234
print(trainDS_aug)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(classes_t)
print(classes_t_aug)
print(classes)
# Out:
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
#list_images_train_aug = list(images_train_aug.as_numpy_iterator())

# %%
#list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
#labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257

list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
#labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

#list_labels_test= list(labels_test.as_numpy_iterator())
#labels_test_true = []
#for i in list_labels_test:
#       labels_test_true.append(classes[i])
#labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
#images_test_ds = np.array(list_images_test)
print(len(labels_train_true))
print(len(labels_validation_true))
#print(labels_test_true.shape)
print(trainDS_aug)
print(trainDS)
print(validationDS)
#print(testDS)
# Out:
# (800, 300, 300, 3)
# (200, 300, 300, 3)
# 800
# 200
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1].shape)
# Out:
# (300, 300, 3)

# %%
#print(list_images_train_aug[1].shape)

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/BS)
validation_steps = math.ceil(num_images_val/BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)
optimizer = keras.optimizers.Adam(learning_rate=1e-4)


base_model.trainable = True
for layer in base_model.layers[:-80]:
    layer.trainable = False

model.compile(loss ='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS_aug, validation_data=validationDS, epochs=100, batch_size=BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1)
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 55s 552ms/step - accuracy: 0.1917 - loss: 2.2377 - val_accuracy: 0.1100 - val_loss: 2.2968
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.4166 - loss: 1.8328 - val_accuracy: 0.2200 - val_loss: 2.1780
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.5560 - loss: 1.5269 - val_accuracy: 0.3150 - val_loss: 2.0526
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.6497 - loss: 1.2231 - val_accuracy: 0.3400 - val_loss: 1.9186
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.7297 - loss: 0.9656 - val_accuracy: 0.3600 - val_loss: 1.7814
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.7322 - loss: 0.8958 - val_accuracy: 0.4350 - val_loss: 1.6557
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.7831 - loss: 0.6786 - val_accuracy: 0.4800 - val_loss: 1.4876
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8178 - loss: 0.6411 - val_accuracy: 0.5700 - val_loss: 1.3382
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8554 - loss: 0.5381 - val_accuracy: 0.6200 - val_loss: 1.1036
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8505 - loss: 0.4999 - val_accuracy: 0.6750 - val_loss: 0.9701
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8359 - loss: 0.4886 - val_accuracy: 0.7350 - val_loss: 0.8311
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8931 - loss: 0.3697 - val_accuracy: 0.7350 - val_loss: 0.8308
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9068 - loss: 0.3235 - val_accuracy: 0.7500 - val_loss: 0.8314
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9279 - loss: 0.2613 - val_accuracy: 0.7750 - val_loss: 0.7963
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.9363 - loss: 0.2657 - val_accuracy: 0.7600 - val_loss: 0.7914
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9471 - loss: 0.2230 - val_accuracy: 0.7800 - val_loss: 0.7770
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9425 - loss: 0.2105 - val_accuracy: 0.7850 - val_loss: 0.8044
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9521 - loss: 0.1825 - val_accuracy: 0.7900 - val_loss: 0.7728
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.9590 - loss: 0.1597 - val_accuracy: 0.8000 - val_loss: 0.8116
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9457 - loss: 0.1731 - val_accuracy: 0.7800 - val_loss: 0.8147
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9588 - loss: 0.1500 - val_accuracy: 0.7850 - val_loss: 0.7709
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9573 - loss: 0.1468 - val_accuracy: 0.7900 - val_loss: 0.7901
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9751 - loss: 0.1102 - val_accuracy: 0.7900 - val_loss: 0.8450
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.9810 - loss: 0.1020 - val_accuracy: 0.7850 - val_loss: 0.8214
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9698 - loss: 0.0995 - val_accuracy: 0.8000 - val_loss: 0.8323
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9821 - loss: 0.0998 - val_accuracy: 0.7900 - val_loss: 0.7723
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9733 - loss: 0.0917 - val_accuracy: 0.7850 - val_loss: 0.8520
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9769 - loss: 0.0957 - val_accuracy: 0.7950 - val_loss: 0.8080
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9544 - loss: 0.1139 - val_accuracy: 0.7900 - val_loss: 0.8285
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9683 - loss: 0.0972 - val_accuracy: 0.7750 - val_loss: 0.8500
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9774 - loss: 0.0823 - val_accuracy: 0.7900 - val_loss: 0.8879
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9873 - loss: 0.0642 - val_accuracy: 0.7900 - val_loss: 0.9386
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9838 - loss: 0.0737 - val_accuracy: 0.7700 - val_loss: 0.9570
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9819 - loss: 0.0555 - val_accuracy: 0.7900 - val_loss: 0.9207
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9872 - loss: 0.0603 - val_accuracy: 0.8050 - val_loss: 0.8862
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9887 - loss: 0.0571 - val_accuracy: 0.8200 - val_loss: 0.8436
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9792 - loss: 0.0645 - val_accuracy: 0.8000 - val_loss: 0.8802
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9861 - loss: 0.0637 - val_accuracy: 0.8050 - val_loss: 0.8646
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9925 - loss: 0.0357 - val_accuracy: 0.8100 - val_loss: 0.9395
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9946 - loss: 0.0299 - val_accuracy: 0.8050 - val_loss: 0.9216
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9927 - loss: 0.0444 - val_accuracy: 0.8200 - val_loss: 0.9342
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9833 - loss: 0.0626 - val_accuracy: 0.8200 - val_loss: 0.9281
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9859 - loss: 0.0460 - val_accuracy: 0.7950 - val_loss: 0.8624
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9887 - loss: 0.0409 - val_accuracy: 0.8000 - val_loss: 0.8534
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9921 - loss: 0.0388 - val_accuracy: 0.8050 - val_loss: 0.8727
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9906 - loss: 0.0368 - val_accuracy: 0.8200 - val_loss: 0.9133
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9873 - loss: 0.0487 - val_accuracy: 0.8150 - val_loss: 0.9046
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9908 - loss: 0.0333 - val_accuracy: 0.8100 - val_loss: 0.8800
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9951 - loss: 0.0281 - val_accuracy: 0.8150 - val_loss: 0.8766
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9849 - loss: 0.0574 - val_accuracy: 0.8050 - val_loss: 0.9152
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9884 - loss: 0.0520 - val_accuracy: 0.7800 - val_loss: 0.9145
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9833 - loss: 0.0524 - val_accuracy: 0.8050 - val_loss: 0.8519
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9966 - loss: 0.0298 - val_accuracy: 0.8200 - val_loss: 0.8657
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9825 - loss: 0.0509 - val_accuracy: 0.8000 - val_loss: 0.8932
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9870 - loss: 0.0405 - val_accuracy: 0.8000 - val_loss: 0.9501
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9949 - loss: 0.0270 - val_accuracy: 0.8100 - val_loss: 0.9421
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9855 - loss: 0.0300 - val_accuracy: 0.8200 - val_loss: 0.9858
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9976 - loss: 0.0167 - val_accuracy: 0.8200 - val_loss: 0.9725
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9867 - loss: 0.0496 - val_accuracy: 0.8050 - val_loss: 0.9714
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9944 - loss: 0.0242 - val_accuracy: 0.7850 - val_loss: 0.9709
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9927 - loss: 0.0309 - val_accuracy: 0.8000 - val_loss: 1.0362
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9786 - loss: 0.0486 - val_accuracy: 0.8100 - val_loss: 0.9780
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9906 - loss: 0.0332 - val_accuracy: 0.8000 - val_loss: 1.0267
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9842 - loss: 0.0489 - val_accuracy: 0.7950 - val_loss: 0.9927
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9917 - loss: 0.0192 - val_accuracy: 0.7850 - val_loss: 1.0445
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9960 - loss: 0.0258 - val_accuracy: 0.7800 - val_loss: 0.9434
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9947 - loss: 0.0231 - val_accuracy: 0.8200 - val_loss: 0.8886
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9855 - loss: 0.0431 - val_accuracy: 0.7850 - val_loss: 0.9189
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9932 - loss: 0.0212 - val_accuracy: 0.8000 - val_loss: 0.8858
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9919 - loss: 0.0222 - val_accuracy: 0.7900 - val_loss: 0.8925
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9923 - loss: 0.0229 - val_accuracy: 0.8000 - val_loss: 0.8796
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9817 - loss: 0.0415 - val_accuracy: 0.8150 - val_loss: 0.8178
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9971 - loss: 0.0184 - val_accuracy: 0.8250 - val_loss: 0.8401
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9986 - loss: 0.0144 - val_accuracy: 0.8100 - val_loss: 0.8876
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9997 - loss: 0.0104 - val_accuracy: 0.8200 - val_loss: 0.8722
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9993 - loss: 0.0097 - val_accuracy: 0.8250 - val_loss: 0.9010
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9984 - loss: 0.0139 - val_accuracy: 0.8150 - val_loss: 0.9744
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9933 - loss: 0.0203 - val_accuracy: 0.8150 - val_loss: 0.9379
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9963 - loss: 0.0221 - val_accuracy: 0.8300 - val_loss: 0.9091
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9925 - loss: 0.0315 - val_accuracy: 0.8000 - val_loss: 0.8854
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9933 - loss: 0.0272 - val_accuracy: 0.8100 - val_loss: 0.8658
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9873 - loss: 0.0441 - val_accuracy: 0.8150 - val_loss: 0.8922
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9879 - loss: 0.0345 - val_accuracy: 0.8200 - val_loss: 0.9908
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9892 - loss: 0.0280 - val_accuracy: 0.8050 - val_loss: 0.9486
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9888 - loss: 0.0211 - val_accuracy: 0.7950 - val_loss: 0.9296
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.7850 - val_loss: 0.9822
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9882 - loss: 0.0374 - val_accuracy: 0.7950 - val_loss: 0.8473
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9947 - loss: 0.0178 - val_accuracy: 0.8000 - val_loss: 0.9033
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9873 - loss: 0.0338 - val_accuracy: 0.8100 - val_loss: 0.8780
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9938 - loss: 0.0171 - val_accuracy: 0.8150 - val_loss: 0.8954
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9988 - loss: 0.0139 - val_accuracy: 0.8050 - val_loss: 1.0026
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9979 - loss: 0.0130 - val_accuracy: 0.8000 - val_loss: 1.0650
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9921 - loss: 0.0239 - val_accuracy: 0.8050 - val_loss: 1.0420
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9971 - loss: 0.0104 - val_accuracy: 0.7900 - val_loss: 1.0914
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9973 - loss: 0.0098 - val_accuracy: 0.8000 - val_loss: 1.1509
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9882 - loss: 0.0530 - val_accuracy: 0.8100 - val_loss: 0.9593
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9883 - loss: 0.0329 - val_accuracy: 0.7950 - val_loss: 0.9615
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9907 - loss: 0.0252 - val_accuracy: 0.7700 - val_loss: 1.0494
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9907 - loss: 0.0280 - val_accuracy: 0.7800 - val_loss: 1.0012
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9961 - loss: 0.0244 - val_accuracy: 0.7900 - val_loss: 1.0221
# CPU times: user 5min 28s, sys: 1min 44s, total: 7min 13s
# Wall time: 5min 17s

# %%
# Fase 2: Fine-tuning (descongelar parte da base)
base_model.trainable = True

# Congela camadas iniciais e libera só as últimas 20, por exemplo:
#for layer in base_model.layers[:-50]:
#    layer.trainable = False

model.optimizer.learning_rate.assign(1e-5)

#keras.backend.set_value(model.optimizer.learning_rate, 1e-5)

#from tensorflow.keras.optimizers import Adam

#model.compile(optimizer=Adam(1e-5), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Compila com taxa de aprendizado reduzida
#model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-5), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history_finetune = model.fit(trainDS_aug, validation_data=validationDS, epochs=20, batch_size=BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1)
# Out:
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9942 - loss: 0.0200 - val_accuracy: 0.7900 - val_loss: 0.9946
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9953 - loss: 0.0164 - val_accuracy: 0.7950 - val_loss: 0.9832
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9815 - loss: 0.0505 - val_accuracy: 0.7950 - val_loss: 0.9633
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9933 - loss: 0.0213 - val_accuracy: 0.8000 - val_loss: 0.9529
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9964 - loss: 0.0182 - val_accuracy: 0.7950 - val_loss: 0.9504
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9940 - loss: 0.0254 - val_accuracy: 0.8000 - val_loss: 0.9566
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9956 - loss: 0.0146 - val_accuracy: 0.7950 - val_loss: 0.9654
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9923 - loss: 0.0245 - val_accuracy: 0.7950 - val_loss: 0.9698
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9936 - loss: 0.0156 - val_accuracy: 0.7950 - val_loss: 0.9592
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9885 - loss: 0.0246 - val_accuracy: 0.7950 - val_loss: 0.9548
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9970 - loss: 0.0107 - val_accuracy: 0.7950 - val_loss: 0.9473
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9963 - loss: 0.0147 - val_accuracy: 0.8050 - val_loss: 0.9476
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9997 - loss: 0.0137 - val_accuracy: 0.8100 - val_loss: 0.9437
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9979 - loss: 0.0105 - val_accuracy: 0.8050 - val_loss: 0.9367
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9964 - loss: 0.0121 - val_accuracy: 0.8050 - val_loss: 0.9391
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9868 - loss: 0.0274 - val_accuracy: 0.8050 - val_loss: 0.9405
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9971 - loss: 0.0136 - val_accuracy: 0.8050 - val_loss: 0.9335
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9896 - loss: 0.0158 - val_accuracy: 0.8000 - val_loss: 0.9183
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9897 - loss: 0.0195 - val_accuracy: 0.8000 - val_loss: 0.9048
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9959 - loss: 0.0142 - val_accuracy: 0.8050 - val_loss: 0.9034

# %%
acc_phase1 = history.history['accuracy']
val_acc_phase1 = history.history['val_accuracy']

acc_phase2 = history_finetune.history['accuracy']
val_acc_phase2 = history_finetune.history['val_accuracy']

acc_total = acc_phase1 + acc_phase2
val_acc_total = val_acc_phase1 + val_acc_phase2
epochs_total = range(len(acc_total))

plt.figure(figsize=(6,5))
plt.plot(epochs_total, acc_total, label='Training Accuracy')
plt.plot(epochs_total, val_acc_total, label='Validation Accuracy')

# Mark the transition between phases
plt.axvline(x=len(acc_phase1)-1, color='gray', linestyle='--', label='Start of Fine-Tuning')

plt.title('Accuracy - Training and Validation - k3')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/accuracy_genre_mel_k3.pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/acc_total_k3.npy', acc_total)
np.save('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/val_acc_total_k3.npy', val_acc_total)

# %%
model.save('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/model_k3.keras')

# %%
model = keras.models.load_model('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/model_k3.keras')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 112 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

testDS_eval = validationDS.unbatch().batch(32)  # ou validationDS

y_true = []
y_pred = []

for images, labels in testDS_eval:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(labels.numpy())

cm = confusion_matrix(y_true, y_pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step

# %%
# Supondo que você tem class_names do seu dataset
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix - k3")
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/confusionmatrix_genre_mel_k3.pdf')
plt.show()

# %%
from google.colab import runtime
runtime.unassign()

# %% [markdown]
# # k=4

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Musical Genre Classification/Database/genre_specscal_mel_kfold/treinamento4.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "training4")
VAL_DATASET = os.path.join("/content", "validation4")
#TEST_DATASET = os.path.join("/content", "teste1")
#METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(VAL_DATASET) #10 classes
classes = sorted(classes)


def make_dataset(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.resize(image, (300, 300))  # resize para modelos pré-treinados
        image = preprocess_input(image)  # 👈 importante
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    class_names = sorted(os.listdir(path))  # Agora local
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [class_names.index(name.split('/')[-2]) for name in filenames]

    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds, class_names, images_ds, labels_ds

# %%
def make_dataset_predict(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.resize(image, (300, 300))  # resize para modelos pré-treinados
        image = preprocess_input(image)  # 👈 importante
        return image

    def configure_for_performance(ds):
        #ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        #ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    class_names = sorted(os.listdir(path))  # Agora local
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [class_names.index(name.split('/')[-2]) for name in filenames]

    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds, class_names, images_ds, labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset(TRAIN_DATASET, BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_predict(VAL_DATASET, BS) #labels com valores 0 a 234
#testDS, classes_te, images_test, labels_test = make_dataset(TEST_DATASET, BS)
print(trainDS)
print(validationDS)
#print(testDS)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_augmentation(path, batch_size):
    def parse_image_with_stretch_tf(filename, label):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)

        # Stretch horizontal
        stretch_factors = tf.constant([1, 1.1, 1.2, 1.3], dtype=tf.float32)
        idx = tf.random.uniform([], minval=0, maxval=3, dtype=tf.int32)
        stretch = stretch_factors[idx]

        height = tf.shape(image)[0]
        width = tf.cast(tf.shape(image)[1], tf.float32)
        new_width = tf.cast(width * stretch, tf.int32)

        image = tf.image.resize(image, size=[height, new_width])
        image = tf.image.resize_with_crop_or_pad(image, 300, 300)
        image = preprocess_input(image)  # 👈 importante

        # Define forma estática para o grafo entender
        image.set_shape([300, 300, 3])
        return image, label

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(tf.data.AUTOTUNE)
        return ds

    # Carrega nomes e rótulos
    class_names = sorted(os.listdir(path))
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [class_names.index(name.split('/')[-2]) for name in filenames]

    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)

    # Unifica imagens e rótulos ANTES do map
    ds = tf.data.Dataset.zip((filenames_ds, labels_ds))
    ds = ds.map(parse_image_with_stretch_tf, num_parallel_calls=tf.data.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds, class_names

# %%
trainDS_aug, classes_t_aug = make_dataset_augmentation(TRAIN_DATASET, BS) #labels com valores 0 a 234
print(trainDS_aug)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(classes_t)
print(classes_t_aug)
print(classes)
# Out:
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
#list_images_train_aug = list(images_train_aug.as_numpy_iterator())

# %%
#list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
#labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257

list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
#labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

#list_labels_test= list(labels_test.as_numpy_iterator())
#labels_test_true = []
#for i in list_labels_test:
#       labels_test_true.append(classes[i])
#labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
#images_test_ds = np.array(list_images_test)
print(len(labels_train_true))
print(len(labels_validation_true))
#print(labels_test_true.shape)
print(trainDS_aug)
print(trainDS)
print(validationDS)
#print(testDS)
# Out:
# (800, 300, 300, 3)
# (200, 300, 300, 3)
# 800
# 200
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1].shape)
# Out:
# (300, 300, 3)

# %%
#print(list_images_train_aug[1].shape)

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/BS)
validation_steps = math.ceil(num_images_val/BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)
optimizer = keras.optimizers.Adam(learning_rate=1e-4)


base_model.trainable = True
for layer in base_model.layers[:-80]:
    layer.trainable = False

model.compile(loss ='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS_aug, validation_data=validationDS, epochs=100, batch_size=BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1)
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 53s 540ms/step - accuracy: 0.2040 - loss: 2.2331 - val_accuracy: 0.1000 - val_loss: 2.4217
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.4772 - loss: 1.7726 - val_accuracy: 0.1400 - val_loss: 2.3091
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.5696 - loss: 1.4616 - val_accuracy: 0.1650 - val_loss: 2.1744
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.6245 - loss: 1.2429 - val_accuracy: 0.2050 - val_loss: 2.0695
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.6879 - loss: 1.0649 - val_accuracy: 0.3100 - val_loss: 1.9016
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.7391 - loss: 0.9001 - val_accuracy: 0.4050 - val_loss: 1.7395
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.7672 - loss: 0.7724 - val_accuracy: 0.5050 - val_loss: 1.4743
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.7930 - loss: 0.6479 - val_accuracy: 0.6000 - val_loss: 1.2673
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.8206 - loss: 0.5949 - val_accuracy: 0.6400 - val_loss: 1.0833
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.8552 - loss: 0.4915 - val_accuracy: 0.6700 - val_loss: 0.9387
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.8691 - loss: 0.4255 - val_accuracy: 0.7350 - val_loss: 0.8394
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8935 - loss: 0.3800 - val_accuracy: 0.7600 - val_loss: 0.7600
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.9022 - loss: 0.3422 - val_accuracy: 0.7450 - val_loss: 0.7226
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.9238 - loss: 0.2979 - val_accuracy: 0.7600 - val_loss: 0.7132
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.9182 - loss: 0.2910 - val_accuracy: 0.7550 - val_loss: 0.7201
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9403 - loss: 0.2484 - val_accuracy: 0.7700 - val_loss: 0.6629
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.9431 - loss: 0.2098 - val_accuracy: 0.7700 - val_loss: 0.6360
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.9426 - loss: 0.2076 - val_accuracy: 0.7750 - val_loss: 0.6312
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.9426 - loss: 0.2081 - val_accuracy: 0.7750 - val_loss: 0.7438
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.9543 - loss: 0.1713 - val_accuracy: 0.8100 - val_loss: 0.6435
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9482 - loss: 0.1634 - val_accuracy: 0.8000 - val_loss: 0.7332
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.9716 - loss: 0.1172 - val_accuracy: 0.8000 - val_loss: 0.6702
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.9704 - loss: 0.1037 - val_accuracy: 0.8100 - val_loss: 0.6611
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9688 - loss: 0.1200 - val_accuracy: 0.8050 - val_loss: 0.6530
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9613 - loss: 0.1211 - val_accuracy: 0.8000 - val_loss: 0.6515
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9790 - loss: 0.0795 - val_accuracy: 0.7800 - val_loss: 0.6660
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9696 - loss: 0.1030 - val_accuracy: 0.7900 - val_loss: 0.6775
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9843 - loss: 0.0926 - val_accuracy: 0.7900 - val_loss: 0.6644
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9728 - loss: 0.1002 - val_accuracy: 0.7700 - val_loss: 0.7394
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9665 - loss: 0.0944 - val_accuracy: 0.7850 - val_loss: 0.7593
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9709 - loss: 0.0999 - val_accuracy: 0.7900 - val_loss: 0.6845
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9795 - loss: 0.0724 - val_accuracy: 0.8000 - val_loss: 0.7648
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9886 - loss: 0.0649 - val_accuracy: 0.7900 - val_loss: 0.7603
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9880 - loss: 0.0634 - val_accuracy: 0.7900 - val_loss: 0.7601
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9878 - loss: 0.0530 - val_accuracy: 0.7800 - val_loss: 0.6985
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9888 - loss: 0.0558 - val_accuracy: 0.7800 - val_loss: 0.7326
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9914 - loss: 0.0357 - val_accuracy: 0.8100 - val_loss: 0.6909
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9891 - loss: 0.0466 - val_accuracy: 0.7900 - val_loss: 0.7132
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9853 - loss: 0.0550 - val_accuracy: 0.7700 - val_loss: 0.7914
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9941 - loss: 0.0484 - val_accuracy: 0.7750 - val_loss: 0.7705
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9853 - loss: 0.0535 - val_accuracy: 0.7900 - val_loss: 0.7107
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9748 - loss: 0.0758 - val_accuracy: 0.7950 - val_loss: 0.7714
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9878 - loss: 0.0512 - val_accuracy: 0.8050 - val_loss: 0.6660
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9885 - loss: 0.0565 - val_accuracy: 0.8100 - val_loss: 0.7042
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9878 - loss: 0.0510 - val_accuracy: 0.8200 - val_loss: 0.7157
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9773 - loss: 0.0752 - val_accuracy: 0.8150 - val_loss: 0.8032
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9822 - loss: 0.0449 - val_accuracy: 0.8150 - val_loss: 0.7312
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9786 - loss: 0.0679 - val_accuracy: 0.7950 - val_loss: 0.8068
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9891 - loss: 0.0328 - val_accuracy: 0.7900 - val_loss: 0.7600
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9979 - loss: 0.0274 - val_accuracy: 0.7850 - val_loss: 0.8216
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9826 - loss: 0.0420 - val_accuracy: 0.8000 - val_loss: 0.7343
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9914 - loss: 0.0451 - val_accuracy: 0.7900 - val_loss: 0.8196
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9902 - loss: 0.0624 - val_accuracy: 0.7850 - val_loss: 0.7590
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9949 - loss: 0.0359 - val_accuracy: 0.8050 - val_loss: 0.7362
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9870 - loss: 0.0463 - val_accuracy: 0.8100 - val_loss: 0.7060
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9937 - loss: 0.0292 - val_accuracy: 0.7850 - val_loss: 0.7375
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9929 - loss: 0.0327 - val_accuracy: 0.7950 - val_loss: 0.7890
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9878 - loss: 0.0554 - val_accuracy: 0.7750 - val_loss: 0.8174
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9861 - loss: 0.0460 - val_accuracy: 0.7650 - val_loss: 0.9233
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9860 - loss: 0.0442 - val_accuracy: 0.7800 - val_loss: 0.8617
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9923 - loss: 0.0307 - val_accuracy: 0.7900 - val_loss: 0.8148
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9917 - loss: 0.0233 - val_accuracy: 0.7950 - val_loss: 0.7877
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9907 - loss: 0.0394 - val_accuracy: 0.7800 - val_loss: 0.7904
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9943 - loss: 0.0382 - val_accuracy: 0.7950 - val_loss: 0.8003
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9946 - loss: 0.0298 - val_accuracy: 0.7900 - val_loss: 0.8093
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9963 - loss: 0.0176 - val_accuracy: 0.7800 - val_loss: 0.8082
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9927 - loss: 0.0270 - val_accuracy: 0.8000 - val_loss: 0.8845
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9913 - loss: 0.0290 - val_accuracy: 0.8050 - val_loss: 0.8730
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9934 - loss: 0.0389 - val_accuracy: 0.8000 - val_loss: 0.9025
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9865 - loss: 0.0359 - val_accuracy: 0.7850 - val_loss: 0.9949
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9936 - loss: 0.0286 - val_accuracy: 0.7950 - val_loss: 0.8526
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9818 - loss: 0.0488 - val_accuracy: 0.7650 - val_loss: 0.9602
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9865 - loss: 0.0510 - val_accuracy: 0.8050 - val_loss: 0.7583
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9903 - loss: 0.0439 - val_accuracy: 0.8050 - val_loss: 0.8036
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9897 - loss: 0.0237 - val_accuracy: 0.7900 - val_loss: 0.7787
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9822 - loss: 0.0570 - val_accuracy: 0.7850 - val_loss: 0.8443
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9940 - loss: 0.0250 - val_accuracy: 0.7900 - val_loss: 0.8151
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9960 - loss: 0.0142 - val_accuracy: 0.8050 - val_loss: 0.8347
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9872 - loss: 0.0306 - val_accuracy: 0.7850 - val_loss: 0.8058
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9910 - loss: 0.0313 - val_accuracy: 0.8150 - val_loss: 0.7881
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9858 - loss: 0.0334 - val_accuracy: 0.8050 - val_loss: 0.8481
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9954 - loss: 0.0190 - val_accuracy: 0.8100 - val_loss: 0.8500
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9903 - loss: 0.0264 - val_accuracy: 0.8150 - val_loss: 0.7865
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9893 - loss: 0.0377 - val_accuracy: 0.7950 - val_loss: 0.8114
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9914 - loss: 0.0165 - val_accuracy: 0.7950 - val_loss: 0.8275
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9942 - loss: 0.0285 - val_accuracy: 0.8050 - val_loss: 0.8885
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9965 - loss: 0.0222 - val_accuracy: 0.7950 - val_loss: 0.8485
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9898 - loss: 0.0303 - val_accuracy: 0.7600 - val_loss: 1.0120
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9992 - loss: 0.0129 - val_accuracy: 0.7900 - val_loss: 0.8641
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9907 - loss: 0.0285 - val_accuracy: 0.7900 - val_loss: 0.8720
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9878 - loss: 0.0359 - val_accuracy: 0.8200 - val_loss: 0.8110
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9976 - loss: 0.0149 - val_accuracy: 0.8100 - val_loss: 0.7601
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9885 - loss: 0.0377 - val_accuracy: 0.7950 - val_loss: 0.8105
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9911 - loss: 0.0251 - val_accuracy: 0.8000 - val_loss: 0.7980
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9866 - loss: 0.0312 - val_accuracy: 0.8200 - val_loss: 0.8289
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9985 - loss: 0.0142 - val_accuracy: 0.8200 - val_loss: 0.7637
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9971 - loss: 0.0144 - val_accuracy: 0.8350 - val_loss: 0.7458
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9889 - loss: 0.0246 - val_accuracy: 0.8150 - val_loss: 0.8090
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9922 - loss: 0.0299 - val_accuracy: 0.7750 - val_loss: 0.9656
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9869 - loss: 0.0418 - val_accuracy: 0.8000 - val_loss: 0.8443
# CPU times: user 5min 14s, sys: 1min 43s, total: 6min 57s
# Wall time: 5min 14s

# %%
# Fase 2: Fine-tuning (descongelar parte da base)
base_model.trainable = True

# Congela camadas iniciais e libera só as últimas 20, por exemplo:
#for layer in base_model.layers[:-50]:
#    layer.trainable = False

model.optimizer.learning_rate.assign(1e-5)

#keras.backend.set_value(model.optimizer.learning_rate, 1e-5)

#from tensorflow.keras.optimizers import Adam

#model.compile(optimizer=Adam(1e-5), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Compila com taxa de aprendizado reduzida
#model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-5), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history_finetune = model.fit(trainDS_aug, validation_data=validationDS, epochs=20, batch_size=BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1)
# Out:
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9983 - loss: 0.0133 - val_accuracy: 0.8000 - val_loss: 0.8265
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9934 - loss: 0.0301 - val_accuracy: 0.8000 - val_loss: 0.8178
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9940 - loss: 0.0170 - val_accuracy: 0.8050 - val_loss: 0.8161
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9866 - loss: 0.0271 - val_accuracy: 0.8100 - val_loss: 0.8014
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9925 - loss: 0.0202 - val_accuracy: 0.8150 - val_loss: 0.7968
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9965 - loss: 0.0109 - val_accuracy: 0.8150 - val_loss: 0.8072
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9951 - loss: 0.0242 - val_accuracy: 0.8050 - val_loss: 0.8140
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9935 - loss: 0.0252 - val_accuracy: 0.8100 - val_loss: 0.8117
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9928 - loss: 0.0319 - val_accuracy: 0.8100 - val_loss: 0.8197
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9901 - loss: 0.0224 - val_accuracy: 0.8050 - val_loss: 0.8278
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9986 - loss: 0.0128 - val_accuracy: 0.8050 - val_loss: 0.8424
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9993 - loss: 0.0147 - val_accuracy: 0.8050 - val_loss: 0.8526
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9917 - loss: 0.0126 - val_accuracy: 0.8100 - val_loss: 0.8648
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9943 - loss: 0.0167 - val_accuracy: 0.8100 - val_loss: 0.8678
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9976 - loss: 0.0100 - val_accuracy: 0.8050 - val_loss: 0.8710
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9961 - loss: 0.0098 - val_accuracy: 0.8050 - val_loss: 0.8708
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9912 - loss: 0.0213 - val_accuracy: 0.8100 - val_loss: 0.8631
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9973 - loss: 0.0183 - val_accuracy: 0.8050 - val_loss: 0.8622
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9948 - loss: 0.0172 - val_accuracy: 0.8150 - val_loss: 0.8547
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9967 - loss: 0.0142 - val_accuracy: 0.8150 - val_loss: 0.8459

# %%
acc_phase1 = history.history['accuracy']
val_acc_phase1 = history.history['val_accuracy']

acc_phase2 = history_finetune.history['accuracy']
val_acc_phase2 = history_finetune.history['val_accuracy']

acc_total = acc_phase1 + acc_phase2
val_acc_total = val_acc_phase1 + val_acc_phase2
epochs_total = range(len(acc_total))

plt.figure(figsize=(6,5))
plt.plot(epochs_total, acc_total, label='Training Accuracy')
plt.plot(epochs_total, val_acc_total, label='Validation Accuracy')

# Mark the transition between phases
plt.axvline(x=len(acc_phase1)-1, color='gray', linestyle='--', label='Start of Fine-Tuning')

plt.title('Accuracy - Training and Validation - k4')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/accuracy_genre_mel_k4.pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/acc_total_k4.npy', acc_total)
np.save('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/val_acc_total_k4.npy', val_acc_total)

# %%
model.save('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/model_k4.keras')

# %%
model = keras.models.load_model('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/model_k4.keras')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 112 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

testDS_eval = validationDS.unbatch().batch(32)  # ou validationDS

y_true = []
y_pred = []

for images, labels in testDS_eval:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(labels.numpy())

cm = confusion_matrix(y_true, y_pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step

# %%
# Supondo que você tem class_names do seu dataset
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix - k4")
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/confusionmatrix_genre_mel_k4.pdf')
plt.show()

# %%
from google.colab import runtime
runtime.unassign()

# %% [markdown]
# # k=5

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Musical Genre Classification/Database/genre_specscal_mel_kfold/treinamento5.zip", 'r')
zip_ref.extractall("/content")
zip_ref.close()

# %% [markdown]
# ### Tensors Definitions

# %%
TRAIN_DATASET = os.path.join("/content", "training5")
VAL_DATASET = os.path.join("/content", "validation5")
#TEST_DATASET = os.path.join("/content", "teste1")
#METRONOMOS_DATASET = os.path.join("/content/drive/MyDrive/Database", "metronomos_review")

classes = os.listdir(VAL_DATASET) #10 classes
classes = sorted(classes)


def make_dataset(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.resize(image, (300, 300))  # resize para modelos pré-treinados
        image = preprocess_input(image)  # 👈 importante
        return image

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    class_names = sorted(os.listdir(path))  # Agora local
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [class_names.index(name.split('/')[-2]) for name in filenames]

    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds, class_names, images_ds, labels_ds

# %%
def make_dataset_predict(path, batch_size):
    def parse_image(filename):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.resize(image, (300, 300))  # resize para modelos pré-treinados
        image = preprocess_input(image)  # 👈 importante
        return image

    def configure_for_performance(ds):
        #ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        #ds = ds.repeat()
        ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
        return ds

    class_names = sorted(os.listdir(path))  # Agora local
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [class_names.index(name.split('/')[-2]) for name in filenames]

    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    images_ds = filenames_ds.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)
    ds = tf.data.Dataset.zip((images_ds, labels_ds))
    ds = configure_for_performance(ds)

    return ds, class_names, images_ds, labels_ds

# %%
trainDS, classes_t, images_train, labels_train = make_dataset(TRAIN_DATASET, BS) #labels com valores 0 a 234
validationDS, classes_v, images_validation, labels_validation = make_dataset_predict(VAL_DATASET, BS) #labels com valores 0 a 234
#testDS, classes_te, images_test, labels_test = make_dataset(TEST_DATASET, BS)
print(trainDS)
print(validationDS)
#print(testDS)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def make_dataset_augmentation(path, batch_size):
    def parse_image_with_stretch_tf(filename, label):
        image = tf.io.read_file(filename)
        image = tf.image.decode_jpeg(image, channels=3)

        # Stretch horizontal
        stretch_factors = tf.constant([1, 1.1, 1.2, 1.3], dtype=tf.float32)
        idx = tf.random.uniform([], minval=0, maxval=3, dtype=tf.int32)
        stretch = stretch_factors[idx]

        height = tf.shape(image)[0]
        width = tf.cast(tf.shape(image)[1], tf.float32)
        new_width = tf.cast(width * stretch, tf.int32)

        image = tf.image.resize(image, size=[height, new_width])
        image = tf.image.resize_with_crop_or_pad(image, 300, 300)
        image = preprocess_input(image)  # 👈 importante

        # Define forma estática para o grafo entender
        image.set_shape([300, 300, 3])
        return image, label

    def configure_for_performance(ds):
        ds = ds.shuffle(buffer_size=1000)
        ds = ds.batch(batch_size)
        ds = ds.repeat()
        ds = ds.prefetch(tf.data.AUTOTUNE)
        return ds

    # Carrega nomes e rótulos
    class_names = sorted(os.listdir(path))
    filenames = glob(path + '/*/*')
    random.shuffle(filenames)
    labels = [class_names.index(name.split('/')[-2]) for name in filenames]

    filenames_ds = tf.data.Dataset.from_tensor_slices(filenames)
    labels_ds = tf.data.Dataset.from_tensor_slices(labels)

    # Unifica imagens e rótulos ANTES do map
    ds = tf.data.Dataset.zip((filenames_ds, labels_ds))
    ds = ds.map(parse_image_with_stretch_tf, num_parallel_calls=tf.data.AUTOTUNE)
    ds = configure_for_performance(ds)

    return ds, class_names

# %%
trainDS_aug, classes_t_aug = make_dataset_augmentation(TRAIN_DATASET, BS) #labels com valores 0 a 234
print(trainDS_aug)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(classes_t)
print(classes_t_aug)
print(classes)
# Out:
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']

# %%
list_images_train = list(images_train.as_numpy_iterator())

# %%
list_images_validation = list(images_validation.as_numpy_iterator())

# %%
#list_images_train_aug = list(images_train_aug.as_numpy_iterator())

# %%
#list_images_test = list(images_test.as_numpy_iterator())

# %%
list_labels_train = list(labels_train.as_numpy_iterator())
labels_train_true = []
for i in list_labels_train:
       labels_train_true.append(classes[i])
#labels_train_true = np.array(labels_train_true, int) #labels de 23 a 257

list_labels_validation = list(labels_validation.as_numpy_iterator())
labels_validation_true = []
for i in list_labels_validation:
       labels_validation_true.append(classes[i])
#labels_validation_true = np.array(labels_validation_true, int)  #labels de 23 a 257

#list_labels_test= list(labels_test.as_numpy_iterator())
#labels_test_true = []
#for i in list_labels_test:
#       labels_test_true.append(classes[i])
#labels_test_true = np.array(labels_test_true, int)  #labels de 23 a 257

# %%
images_train_ds = np.array(list_images_train)
print(images_train_ds.shape)
images_validation_ds = np.array(list_images_validation)
print(images_validation_ds.shape)
#images_test_ds = np.array(list_images_test)
print(len(labels_train_true))
print(len(labels_validation_true))
#print(labels_test_true.shape)
print(trainDS_aug)
print(trainDS)
print(validationDS)
#print(testDS)
# Out:
# (800, 300, 300, 3)
# (200, 300, 300, 3)
# 800
# 200
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(images_train_ds[1].shape)
# Out:
# (300, 300, 3)

# %%
#print(list_images_train_aug[1].shape)

# %%
num_images_predict = len(glob(TRAIN_DATASET + '/*/*'))
num_images_val = len(glob(VAL_DATASET + '/*/*'))
steps_per_epoch_predict =math.ceil(num_images_predict/BS)
validation_steps = math.ceil(num_images_val/BS)

#Criando o multilabel binarizer:

mlb = MultiLabelBinarizer()
dicionario = mlb.fit_transform([classes])

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)
optimizer = keras.optimizers.Adam(learning_rate=1e-4)


base_model.trainable = True
for layer in base_model.layers[:-80]:
    layer.trainable = False

model.compile(loss ='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# ### Model.fit

# %%
# %%time
history = model.fit(trainDS_aug, validation_data=validationDS, epochs=100, batch_size=BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1)
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 54s 559ms/step - accuracy: 0.1508 - loss: 2.2851 - val_accuracy: 0.0600 - val_loss: 2.4362
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.3921 - loss: 1.8631 - val_accuracy: 0.1400 - val_loss: 2.2928
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.5829 - loss: 1.5063 - val_accuracy: 0.1950 - val_loss: 2.1788
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.6059 - loss: 1.2956 - val_accuracy: 0.2700 - val_loss: 2.0519
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.6750 - loss: 1.0484 - val_accuracy: 0.3800 - val_loss: 1.8357
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.7668 - loss: 0.8119 - val_accuracy: 0.4250 - val_loss: 1.6727
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.7530 - loss: 0.7623 - val_accuracy: 0.5050 - val_loss: 1.3685
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.7837 - loss: 0.6897 - val_accuracy: 0.6000 - val_loss: 1.1414
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8166 - loss: 0.5724 - val_accuracy: 0.6350 - val_loss: 1.1095
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8549 - loss: 0.5206 - val_accuracy: 0.6650 - val_loss: 0.9750
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8658 - loss: 0.4421 - val_accuracy: 0.6700 - val_loss: 0.8709
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8867 - loss: 0.3961 - val_accuracy: 0.6850 - val_loss: 0.8485
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9015 - loss: 0.3772 - val_accuracy: 0.7000 - val_loss: 0.7797
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9375 - loss: 0.2842 - val_accuracy: 0.7250 - val_loss: 0.7680
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9257 - loss: 0.2535 - val_accuracy: 0.7050 - val_loss: 0.8430
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9257 - loss: 0.2390 - val_accuracy: 0.7100 - val_loss: 0.6802
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9266 - loss: 0.2524 - val_accuracy: 0.7400 - val_loss: 0.7293
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9528 - loss: 0.1865 - val_accuracy: 0.7450 - val_loss: 0.7087
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9631 - loss: 0.1476 - val_accuracy: 0.7450 - val_loss: 0.7521
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9590 - loss: 0.1830 - val_accuracy: 0.7600 - val_loss: 0.6733
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9597 - loss: 0.1555 - val_accuracy: 0.7650 - val_loss: 0.7125
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9645 - loss: 0.1416 - val_accuracy: 0.7600 - val_loss: 0.6926
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9716 - loss: 0.1113 - val_accuracy: 0.7550 - val_loss: 0.7344
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9614 - loss: 0.1354 - val_accuracy: 0.7700 - val_loss: 0.7406
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9731 - loss: 0.1031 - val_accuracy: 0.7750 - val_loss: 0.7054
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9676 - loss: 0.1314 - val_accuracy: 0.7900 - val_loss: 0.7065
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9631 - loss: 0.1327 - val_accuracy: 0.7700 - val_loss: 0.6993
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9628 - loss: 0.1124 - val_accuracy: 0.7600 - val_loss: 0.7188
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9872 - loss: 0.0719 - val_accuracy: 0.7550 - val_loss: 0.7399
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9831 - loss: 0.0719 - val_accuracy: 0.7650 - val_loss: 0.7229
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9782 - loss: 0.0906 - val_accuracy: 0.7750 - val_loss: 0.7316
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9752 - loss: 0.0898 - val_accuracy: 0.7650 - val_loss: 0.7768
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9819 - loss: 0.0692 - val_accuracy: 0.7600 - val_loss: 0.8057
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9743 - loss: 0.0728 - val_accuracy: 0.7850 - val_loss: 0.7190
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9783 - loss: 0.0727 - val_accuracy: 0.7750 - val_loss: 0.7792
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9850 - loss: 0.0608 - val_accuracy: 0.7700 - val_loss: 0.7216
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9867 - loss: 0.0586 - val_accuracy: 0.7750 - val_loss: 0.7680
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9888 - loss: 0.0589 - val_accuracy: 0.7700 - val_loss: 0.7863
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9954 - loss: 0.0342 - val_accuracy: 0.7700 - val_loss: 0.8437
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9897 - loss: 0.0476 - val_accuracy: 0.7700 - val_loss: 0.9197
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9836 - loss: 0.0700 - val_accuracy: 0.7750 - val_loss: 0.8193
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9753 - loss: 0.0693 - val_accuracy: 0.7750 - val_loss: 0.8710
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9841 - loss: 0.0663 - val_accuracy: 0.7750 - val_loss: 0.8689
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9872 - loss: 0.0510 - val_accuracy: 0.7800 - val_loss: 0.8335
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9867 - loss: 0.0504 - val_accuracy: 0.8000 - val_loss: 0.8196
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9914 - loss: 0.0380 - val_accuracy: 0.7700 - val_loss: 0.8936
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9960 - loss: 0.0282 - val_accuracy: 0.7700 - val_loss: 0.9113
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9798 - loss: 0.0449 - val_accuracy: 0.7600 - val_loss: 0.8253
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9871 - loss: 0.0524 - val_accuracy: 0.7650 - val_loss: 0.9653
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9864 - loss: 0.0505 - val_accuracy: 0.7750 - val_loss: 0.8136
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9847 - loss: 0.0485 - val_accuracy: 0.7600 - val_loss: 0.8331
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9921 - loss: 0.0316 - val_accuracy: 0.7400 - val_loss: 0.8622
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9921 - loss: 0.0363 - val_accuracy: 0.7650 - val_loss: 0.8654
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9887 - loss: 0.0385 - val_accuracy: 0.7650 - val_loss: 0.8510
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9853 - loss: 0.0493 - val_accuracy: 0.7450 - val_loss: 1.0012
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9810 - loss: 0.0409 - val_accuracy: 0.7750 - val_loss: 0.8625
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9876 - loss: 0.0570 - val_accuracy: 0.7550 - val_loss: 0.9270
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9888 - loss: 0.0501 - val_accuracy: 0.7700 - val_loss: 0.8193
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9777 - loss: 0.0623 - val_accuracy: 0.7950 - val_loss: 0.7739
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9888 - loss: 0.0401 - val_accuracy: 0.7850 - val_loss: 0.9080
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9849 - loss: 0.0461 - val_accuracy: 0.7800 - val_loss: 0.8347
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9874 - loss: 0.0426 - val_accuracy: 0.7800 - val_loss: 0.8456
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9931 - loss: 0.0315 - val_accuracy: 0.7900 - val_loss: 0.8773
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9887 - loss: 0.0458 - val_accuracy: 0.8050 - val_loss: 0.8818
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9798 - loss: 0.0520 - val_accuracy: 0.7500 - val_loss: 0.9440
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9935 - loss: 0.0248 - val_accuracy: 0.7800 - val_loss: 0.9005
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9897 - loss: 0.0422 - val_accuracy: 0.7800 - val_loss: 0.8324
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9876 - loss: 0.0309 - val_accuracy: 0.8050 - val_loss: 0.7975
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9927 - loss: 0.0260 - val_accuracy: 0.7850 - val_loss: 0.8056
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9912 - loss: 0.0393 - val_accuracy: 0.7950 - val_loss: 0.8168
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9911 - loss: 0.0241 - val_accuracy: 0.7900 - val_loss: 0.8321
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9910 - loss: 0.0370 - val_accuracy: 0.7850 - val_loss: 0.8285
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9953 - loss: 0.0182 - val_accuracy: 0.7850 - val_loss: 0.8605
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9950 - loss: 0.0252 - val_accuracy: 0.7600 - val_loss: 0.8233
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9976 - loss: 0.0228 - val_accuracy: 0.7850 - val_loss: 0.8431
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9984 - loss: 0.0163 - val_accuracy: 0.7750 - val_loss: 0.9194
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9938 - loss: 0.0241 - val_accuracy: 0.7800 - val_loss: 0.8812
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9903 - loss: 0.0307 - val_accuracy: 0.7900 - val_loss: 0.8675
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9947 - loss: 0.0223 - val_accuracy: 0.7900 - val_loss: 0.8758
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9872 - loss: 0.0302 - val_accuracy: 0.7750 - val_loss: 0.9299
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9909 - loss: 0.0389 - val_accuracy: 0.7650 - val_loss: 0.9789
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9817 - loss: 0.0684 - val_accuracy: 0.7650 - val_loss: 1.0380
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9930 - loss: 0.0388 - val_accuracy: 0.7550 - val_loss: 0.9585
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9945 - loss: 0.0207 - val_accuracy: 0.7550 - val_loss: 1.0351
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9905 - loss: 0.0382 - val_accuracy: 0.7600 - val_loss: 0.9863
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9976 - loss: 0.0122 - val_accuracy: 0.7450 - val_loss: 0.9476
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9931 - loss: 0.0266 - val_accuracy: 0.7600 - val_loss: 0.9291
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9943 - loss: 0.0202 - val_accuracy: 0.7800 - val_loss: 0.8804
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9952 - loss: 0.0195 - val_accuracy: 0.7950 - val_loss: 0.9414
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9934 - loss: 0.0214 - val_accuracy: 0.7750 - val_loss: 0.9286
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9961 - loss: 0.0231 - val_accuracy: 0.7650 - val_loss: 1.0005
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9867 - loss: 0.0406 - val_accuracy: 0.7650 - val_loss: 0.9167
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9955 - loss: 0.0145 - val_accuracy: 0.7700 - val_loss: 0.9810
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9949 - loss: 0.0120 - val_accuracy: 0.7750 - val_loss: 1.1008
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9936 - loss: 0.0222 - val_accuracy: 0.7650 - val_loss: 1.0369
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9896 - loss: 0.0335 - val_accuracy: 0.7600 - val_loss: 1.0235
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9911 - loss: 0.0275 - val_accuracy: 0.7900 - val_loss: 0.9739
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9988 - loss: 0.0093 - val_accuracy: 0.7900 - val_loss: 0.9914
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.7800 - val_loss: 0.9764
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9942 - loss: 0.0220 - val_accuracy: 0.7650 - val_loss: 0.9041
# CPU times: user 5min 17s, sys: 1min 40s, total: 6min 58s
# Wall time: 5min 16s

# %%
# Fase 2: Fine-tuning (descongelar parte da base)
base_model.trainable = True

# Congela camadas iniciais e libera só as últimas 20, por exemplo:
#for layer in base_model.layers[:-50]:
#    layer.trainable = False

model.optimizer.learning_rate.assign(1e-5)

#keras.backend.set_value(model.optimizer.learning_rate, 1e-5)

#from tensorflow.keras.optimizers import Adam

#model.compile(optimizer=Adam(1e-5), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Compila com taxa de aprendizado reduzida
#model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-5), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history_finetune = model.fit(trainDS_aug, validation_data=validationDS, epochs=20, batch_size=BS, steps_per_epoch=steps_per_epoch_predict,  validation_steps=validation_steps ,verbose=1)
# Out:
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9876 - loss: 0.0277 - val_accuracy: 0.7650 - val_loss: 0.9045
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9959 - loss: 0.0149 - val_accuracy: 0.7700 - val_loss: 0.9014
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9966 - loss: 0.0146 - val_accuracy: 0.7650 - val_loss: 0.9023
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9913 - loss: 0.0189 - val_accuracy: 0.7700 - val_loss: 0.8922
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9995 - loss: 0.0110 - val_accuracy: 0.7700 - val_loss: 0.8944
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9952 - loss: 0.0203 - val_accuracy: 0.7750 - val_loss: 0.8928
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9910 - loss: 0.0256 - val_accuracy: 0.7750 - val_loss: 0.8890
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9942 - loss: 0.0178 - val_accuracy: 0.7750 - val_loss: 0.8884
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9905 - loss: 0.0202 - val_accuracy: 0.7700 - val_loss: 0.8838
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9946 - loss: 0.0177 - val_accuracy: 0.7700 - val_loss: 0.8820
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9968 - loss: 0.0147 - val_accuracy: 0.7700 - val_loss: 0.8782
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9967 - loss: 0.0137 - val_accuracy: 0.7800 - val_loss: 0.8774
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9928 - loss: 0.0196 - val_accuracy: 0.7900 - val_loss: 0.8856
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9897 - loss: 0.0158 - val_accuracy: 0.7900 - val_loss: 0.8879
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9937 - loss: 0.0193 - val_accuracy: 0.7850 - val_loss: 0.8896
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9962 - loss: 0.0133 - val_accuracy: 0.7900 - val_loss: 0.8878
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9946 - loss: 0.0200 - val_accuracy: 0.7850 - val_loss: 0.8841
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9982 - loss: 0.0124 - val_accuracy: 0.7800 - val_loss: 0.8835
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9980 - loss: 0.0091 - val_accuracy: 0.7850 - val_loss: 0.8850
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9948 - loss: 0.0136 - val_accuracy: 0.7850 - val_loss: 0.8847

# %%
acc_phase1 = history.history['accuracy']
val_acc_phase1 = history.history['val_accuracy']

acc_phase2 = history_finetune.history['accuracy']
val_acc_phase2 = history_finetune.history['val_accuracy']

acc_total = acc_phase1 + acc_phase2
val_acc_total = val_acc_phase1 + val_acc_phase2
epochs_total = range(len(acc_total))

plt.figure(figsize=(6,5))
plt.plot(epochs_total, acc_total, label='Training Accuracy')
plt.plot(epochs_total, val_acc_total, label='Validation Accuracy')

# Mark the transition between phases
plt.axvline(x=len(acc_phase1)-1, color='gray', linestyle='--', label='Start of Fine-Tuning')

plt.title('Accuracy - Training and Validation - k5')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/accuracy_genre_mel_k5.pdf')
plt.show()

# %%
np.save('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/acc_total_k5.npy', acc_total)
np.save('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/val_acc_total_k5.npy', val_acc_total)

# %%
model.save('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/model_k5.keras')

# %%
model = keras.models.load_model('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/model_k5.keras')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 112 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

testDS_eval = validationDS.unbatch().batch(32)  # ou validationDS

y_true = []
y_pred = []

for images, labels in testDS_eval:
    preds = model.predict(images)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(labels.numpy())

cm = confusion_matrix(y_true, y_pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step

# %%
# Supondo que você tem class_names do seu dataset
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix - k5")
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold/confusionmatrix_genre_mel_k5.pdf')
plt.show()

# %%
from google.colab import runtime
runtime.unassign()

# %% [markdown]
# # Geração de Tabela

# %%
import numpy as np
import pandas as pd
import os

# Diretório base onde os arquivos estão salvos
base_path = "/content/drive/MyDrive/Musical Genre Classification/Resultados/efficientnetb0_genre_specscal_mel_kfold"

# Inicializa dicionários para os resultados
final_train_acc = {}
max_train_acc = {}
final_val_acc = {}
max_val_acc = {}

# Loop para k = 1 até 5
for k in range(1, 6):
    acc_path = os.path.join(base_path, f"acc_total_k{k}.npy")
    val_acc_path = os.path.join(base_path, f"val_acc_total_k{k}.npy")

    acc = np.load(acc_path)
    val_acc = np.load(val_acc_path)

    final_train_acc[f'k{k}'] = acc[-1]
    max_train_acc[f'k{k}'] = np.max(acc)
    final_val_acc[f'k{k}'] = val_acc[-1]
    max_val_acc[f'k{k}'] = np.max(val_acc)

# Calcula a média e desvio padrão para cada linha
def add_resultado_final_std(row):
    valores = np.array([v for v in row.values()])
    return np.mean(valores), np.std(valores)

# Construindo DataFrame
df = pd.DataFrame({
    "Acurácia Final - Treinamento": final_train_acc,
    "Valor Máximo Acurácia - Treinamento": max_train_acc,
    "Acurácia Final - Validação": final_val_acc,
    "Valor Máximo Acurácia - Validação": max_val_acc
}).T

# Adiciona colunas de média e desvio padrão
df["Resultado Final"] = df.mean(axis=1)
df["Desvio Padrão"] = df.std(axis=1)

# %%
df
# Out:
#                                           k1      k2       k3       k4  \
# Acurácia Final - Treinamento         0.99375  0.9950  0.99625  0.99625
# Valor Máximo Acurácia - Treinamento  0.99875  0.9975  1.00000  0.99875
# Acurácia Final - Validação           0.78500  0.7900  0.80500  0.81500
# Valor Máximo Acurácia - Validação    0.83000  0.8000  0.83000  0.83500
#
#                                           k5  Resultado Final  Desvio Padrão
# Acurácia Final - Treinamento         0.99375            0.995       0.001118
# Valor Máximo Acurácia - Treinamento  1.00000            0.999       0.000935
# Acurácia Final - Validação           0.78500            0.796       0.012000
# Valor Máximo Acurácia - Validação    0.80500            0.820       0.014491
